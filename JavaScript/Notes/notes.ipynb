# %% [markdown]
# # .gitignore

# %% [markdown]
# - When working with packages that are installed with npm, you don’t need to track the contents of `node_modules` with git, nor push those files to GitHub. As we learned in the npm lesson, the `package.json` file contains all the dependency information, so that anyone can clone your project and install them on their machine with `npm install`.
#
# - You can make a `.gitignore` file in the root of the project, and by writing file or directory names in it, you can tell git what things you don’t want to track. It’s customary to add `node_modules` to `.gitignore`, since it can get really big. Similarly, `dist` is often ignored as it can be generated when someone runs the command to bundle/build the application.
#
# - When creating a new repo on GitHub, there is an option to specify a `.gitignore` template. There are many templates out there that include common files and directories that are not typically tracked based on the type of project or language used. For JavaScript projects, there is a `node` template that includes `node_modules` and `dist`.

# %% [markdown]
# # Organizing JS Code

# %% [markdown]
# ### Objects

# %% [markdown]
# #### Intro

# %% [markdown]
# - Objects: collections of key-value pairs. They can represent real-world entities and their properties/behaviors.
#
# - Object literals: created using curly braces `{}`. Example:
#     ```javascript
#     const person = {
#         name: 'Alice',
#         age: 30,
#         greet() {
#         console.log(`Hello, my name is ${this.name}`);
#         }
#     };
#     ```

# %% [markdown]
# - There are 2 ways to get information from an object:
#     1. Dot notation: `person.name`
#     2. Bracket notation: `person['name']`
#
# 1. `Dot Notation`:
#     - Used when the property name is a valid identifier (no spaces, special characters, or reserved words).
#         - Example: `person.name`
#     - Can't be used on variables or expressions.
#         - Example: `const prop = 'name'; person.prop` (this will not work, it will look for a property named 'prop' instead of 'name')
#
# 2. `Bracket Notation`:
#     - Used when the property name is not a valid identifier or is dynamic.
#         - Example: `person['name']` or `person["first name"]`
#     - Can be used with variables or expressions.
#         - Example: `const prop = 'name'; person[prop]` (this will work, it will look for a property named 'name')

# %% [markdown]
# ##### This Keyword

# %% [markdown]
# - `this` refers to the current object context. It allows access to the object's properties and methods from within its own methods.
#     - Example:
#     ```javascript
#         const person = {
#             name: 'Alice',
#             greet() {
#                 console.log(`Hello, my name is ${this.name}`);
#             }
#         };
#         person.greet(); // Output: Hello, my name is Alice
#      ```
# - The value of `this` can change based on how a function is called. In a method, `this` refers to the object. In a regular function, `this` refers to the global object (or `undefined` in strict mode).
#     - Example:
#     ```javascript
#         function showThis() {
#             console.log(this);
#         }
#     showThis(); // In non-strict mode, this will log the global object (window in browsers). In strict mode, it will log undefined.
# ```

# %% [markdown]
# - In simpler terms, `this` is a special keyword that allows you to refer to the current object within its own methods. It helps you access the object's properties and methods without having to hardcode the object name, making your code more flexible and reusable.
#
# - Example:
#     ```javascript
#         const car = {
#             make: "Volkswagen",
#             model: "Golf",
#             year: 2026,
#             color: "blue",
#             priceUSD: 40000,
#         };
#
#         function displayCarInfo() {
#         console.log(`This car is a ${this.year} ${this.make} ${this.model} in ${this.color} color, priced at $${this.priceUSD}.`);
#         }
#
#         car.displayInfo = displayCarInfo;
#         car.displayInfo(); // Output: This car is a 2026 Volkswagen Golf in blue color, priced at $40000.
#     ```

# %% [markdown]
# #### Object Constructors

# %% [markdown]
# ##### Intro

# %% [markdown]
# - **_Object Constructors_** are functions that create and initialize (construct or in simpler terms, build) objects. They are a way to create multiple instances _(instance is a single object created from a constructor; a constructor is a function used to create and initialize objects)_ of an object with the same structure but different values.

# %% [markdown]
# - Example:
#     ```javascript
#         function Car(make, model, year, color, priceUSD) {
#             this.make = make;
#             this.model = model;
#             this.year = year;
#             this.color = color;
#             this.priceUSD = priceUSD;
#         }
#
#         const car1 = new Car("Volkswagen", "Golf", 2026, "blue", 40000);
#         const car2 = new Car("Toyota", "Camry", 2025, "red", 35000);
#
#         console.log(car1); // Output: Car { make: 'Volkswagen', model: 'Golf', year: 2026, color: 'blue', priceUSD: 40000 }
#         console.log(car2); // Output: Car { make: 'Toyota', model: 'Camry', year: 2025, color: 'red', priceUSD: 35000 }
#     ```
#     - Explanation:
#         - The `Car` function is a constructor that takes parameters to initialize the properties of the car object.
#         - The `new` keyword is used to create new instances of the `Car` object, which allows us to create multiple cars with different properties while sharing the same structure defined by the constructor.
#         - Each instance (car1, car2) has its own set of properties based on the values passed to the constructor.
#         - This approach promotes code reusability and organization when creating multiple objects with similar characteristics.
#         - The `this.name = name;` syntax inside the constructor assigns the value of the `name` parameter to the `name` property of the object being created.

# %% [markdown]
# ##### The Prototype

# %% [markdown]
# - **_Prototypes_** are a fundamental concept in JavaScript that allows objects to inherit properties and methods from other objects. Every JavaScript object has a prototype, which is another object that it can delegate property and method lookups to.
#
# - The prototype is a powerful mechanism for sharing behavior among objects. When you access a property or method on an object, JavaScript first looks for it on the object itself. If it doesn't find it there, it looks up the prototype chain until it finds the property or reaches the end of the chain (null).
#
# - The syntax for adding properties or methods to a constructor's prototype is:
#     ```javascript
#         ConstructorName.prototype.methodName = function() {
#             // method body
#         };
#     ```
# - Example:
#     ```javascript
#         function Car(make, model, year) {
#             this.make = make;
#             this.model = model;
#             this.year = year;
#         }
#
#         Car.prototype.getCarInfo = function() {
#             return `${this.year} ${this.make} ${this.model}`;
#         };
#
#         const car1 = new Car("Volkswagen", "Golf", 2026);
#         console.log(car1.getCarInfo()); // Output: 2026 Volkswagen Golf
#     ```
# - Explanation:
#     - In this example, we define a constructor function `Car` that initializes the properties of a car object.
#     - We then add a method `getCarInfo` to the `Car` prototype, which allows all instances of `Car` to access this method without having to define it on each instance.
#     - When we create an instance `car1` and call `car1.getCarInfo()`, JavaScript looks for the `getCarInfo` method on `car1`. Since it doesn't find it there, it looks up the prototype chain and finds it on `Car.prototype`, allowing us to call the method successfully.

# %% [markdown]
# 1. _All Objects in JS have a `[[Prototype]]`:_
#     - This is an internal property that points to the prototype object from which the object inherits properties and methods. It is not directly accessible in code, but it can be accessed using `Object.getPrototypeOf()` or the `__proto__` property (though the latter is deprecated).
#     - Example:
#     ```javascript
#         const car1 = new Car("Volkswagen", "Golf", 2026);
#         console.log(Object.getPrototypeOf(car1)); // Output: Car { getCarInfo: [Function] }
#     ```
#     - In simpler terms, prototypes allow us to define methods and properties that can be shared across all instances of a constructor function, promoting code reusability and efficient memory usage.
#
#
# 2. _The `[[Prototype]]` is another object:_
#     - The prototype itself is an object that can have its own properties and methods. This means that prototypes can also inherit from other prototypes, creating a chain of inheritance.
#     - Example:
#     ```javascript
#         function Vehicle() {
#             this.type = "vehicle";
#         }
#
#         Vehicle.prototype.getType = function() {
#             return this.type;
#         };
#
#         function Car(make, model, year) {
#             Vehicle.call(this); // Call the Vehicle constructor to initialize the type property
#             this.make = make;
#             this.model = model;
#             this.year = year;
#         }
#
#         Car.prototype = Object.create(Vehicle.prototype); // Set Car's prototype to be an object created from Vehicle's prototype
#         Car.prototype.constructor = Car; // Set the constructor property back to Car
#
#         const car1 = new Car("Volkswagen", "Golf", 2026);
#         console.log(car1.getType()); // Output: vehicle
#     ```
#     - In this example, we have a `Vehicle` constructor with a method `getType`. The `Car` constructor inherits from `Vehicle` by setting its prototype to an object created from `Vehicle.prototype`. This allows instances of `Car` to access the `getType` method defined in `Vehicle`, demonstrating how prototypes can create a chain of inheritance.
#
#
# 3. _That the original object inherits from, has access to all of its `[[Prototype]]` properties and methods:_
#     - When an object inherits from a prototype, it has access to all the properties and methods defined on that prototype. This means that if a property or method is not found on the object itself, JavaScript will look up the prototype chain to find it.
#     - Example:
#     ```javascript
#         function Vehicle() {
#             this.type = "vehicle";
#         }
#
#         Vehicle.prototype.getType = function() {
#             return this.type;
#         };
#
#         function Car(make, model, year) {
#             Vehicle.call(this); // Call the Vehicle constructor to initialize the type property
#             this.make = make;
#             this.model = model;
#             this.year = year;
#         }
#
#         Car.prototype = Object.create(Vehicle.prototype); // Set Car's prototype to be an object created from Vehicle's prototype
#         Car.prototype.constructor = Car; // Set the constructor property back to Car
#
#         const car1 = new Car("Volkswagen", "Golf", 2026);
#         console.log(car1.getType()); // Output: vehicle
#     ```
#     - In this example, `car1` is an instance of `Car`, which inherits from `Vehicle`. Even though `car1` does not have its own `getType` method, it can access it through the prototype chain, demonstrating that the original object (car1) has access to all of its `[[Prototype]]` properties and methods.

# %% [markdown]
# - Why use prototypes?
#     1. We can define properties and functions common among all objects on a prototype to save memory. Defining every property and function takes up a lot of memory, especially if you have a lot of common properties and functions, and a lot of created objects! Defining them on a centralized, shared object which the objects have access to, thus saves memory.
#
#     2. The second reason is the name of this section, `Prototypal Inheritance`, which we’ve referred to in passing earlier, in the introduction to the Prototype. In recap, we can say that the `player1` and `player2` objects inherit from the Player.prototype object, which allows them to access functions like `.sayHello`.

# %% [markdown]
# ### Factory Functions & the Module Pattern

# %% [markdown]
# #### Variable Scope

# %% [markdown]
# - **Scoping:** the accessibility of variables and functions in different parts of the code. JavaScript has function scope and block scope.
#     - **Function scope:** variables declared within a function are only accessible within that function.
#     - **Block scope:** variables declared with `let` or `const` within a block (e.g., inside an `if` statement or a loop) are only accessible within that block.
# - Example:
#     ```javascript
#         function exampleFunction() {
#             var functionScopedVar = "I am function scoped";
#             if (true) {
#                 let blockScopedVar = "I am block scoped";
#                 console.log(functionScopedVar); // Output: I am function scoped
#                 console.log(blockScopedVar); // Output: I am block scoped
#             }
#             console.log(functionScopedVar); // Output: I am function scoped
#             console.log(blockScopedVar); // Error: blockScopedVar is not defined
#         }
#         exampleFunction();
#     ```

# %% [markdown]
# - There are 2 types of scope:
#     1. **Global Scope:** variables declared outside of any function or block are in the global scope and can be accessed from anywhere in the code.
#         - Example:
#         ```javascript
#             var globalVar = "I am global";
#             function exampleFunction() {
#                 console.log(globalVar); // Output: I am global
#             }
#             exampleFunction();
#         ```
#
#     2. **Local Scope:** variables declared within a function or block are in the local scope and can only be accessed within that function or block.
#         - Example:
#         ```javascript
#             function exampleFunction() {
#                 var localVar = "I am local";
#                 console.log(localVar); // Output: I am local
#             }
#             exampleFunction();
#             console.log(localVar); // Error: localVar is not defined
#         ```

# %% [markdown]
# #### Closures

# %% [markdown]
# - **Closures** are a fundamental concept in JavaScript that allows a function to access variables from its outer (enclosing) scope even after the outer function has finished executing. A closure is created when a function is defined inside another function and retains access to the outer function's variables.
# - Example:
#     ```javascript
#         function outerFunction() {
#             let outerVariable = "I am from the outer function";
#
#             function innerFunction() {
#                 console.log(outerVariable); // Output: I am from the outer function
#             }
#
#             return innerFunction;
#         }
#
#         const closureExample = outerFunction();
#         closureExample(); // Output: I am from the outer function
#     ```
#     - Explanation:
#         - In this example, `outerFunction` defines a variable `outerVariable` and an inner function `innerFunction` that accesses `outerVariable`.
#         - When `outerFunction` is called, it returns `innerFunction`, which retains access to `outerVariable` even after `outerFunction` has finished executing. This is the essence of a closure: the inner function "closes over" the variables of the outer function, allowing it to access and manipulate those variables even when the outer function is no longer in scope.

# %% [markdown]
# - **Surrounding State / Lexical Environment:** the variables and functions that are in scope at the time a closure is created. The surrounding state is what allows closures to access and manipulate variables from their outer scope.
# - Example:
#     ```javascript
#         function createCounter() {
#             let count = 0; // This is the surrounding state
#
#             return function() { // This inner function is the closure
#                 count++; // Accessing and modifying the surrounding state
#                 console.log(count);
#             };
#         }
#
#         const counter = createCounter();
#         counter(); // Output: 1
#         counter(); // Output: 2
#         counter(); // Output: 3
#     ```
#     - Explanation:
#         - In this example, `createCounter` initializes a variable `count` and returns an inner function that increments and logs `count`.
#         - The inner function is a closure that has access to the surrounding state (the `count` variable) even after `createCounter` has finished executing. Each time we call `counter()`, it updates and logs the current value of `count`, demonstrating how closures can maintain and manipulate state across multiple invocations.

# %% [markdown]
# #### Factory Functions

# %% [markdown]
# - **Factory Functions** are functions that create and return new objects. They are a way to create multiple instances of an object with the same structure but different values without using classes or constructors.
# - Example:
#     ```javascript
#         function createCar(make, model, year) {
#             return {
#                 make: make,
#                 model: model,
#                 year: year,
#                 getCarInfo() {
#                     return `${this.year} ${this.make} ${this.model}`;
#                 }
#             };
#         }
#
#         const car1 = createCar("Volkswagen", "Golf", 2026);
#         const car2 = createCar("Toyota", "Camry", 2025);
#
#         console.log(car1.getCarInfo()); // Output: 2026 Volkswagen Golf
#         console.log(car2.getCarInfo()); // Output: 2025 Toyota Camry
#     ```
#     - Explanation:
#         - In this example, `createCar` is a factory function that takes parameters to create and return a new car object with properties and a method.
#         - Each time we call `createCar`, it returns a new object with the specified properties and the `getCarInfo` method. This allows us to create multiple car objects with different values while sharing the same structure defined by the factory function.

# %% [markdown]
# - Advantages of using factory functions over constructors:
#     1. Factory functions can return any type of object, not just instances of a specific constructor. This allows for more flexibility in the types of objects that can be created.
#
#     2. Factory functions can have private variables and methods, which are not accessible from outside the function. This allows for better encapsulation and data hiding.
#
#     3. Factory functions do not require the use of the `new` keyword, which can help prevent errors and improve readability.

# %% [markdown]
# #### Private Variables & Functions

# %% [markdown]
# - **Private Variables & Functions** are variables and functions that are not accessible from outside the function or object they are defined in. They are used to encapsulate data and behavior, providing a way to hide implementation details and protect the internal state of an object.
#
# - Example:
#     ```javascript
#         function createCounter() {
#             let count = 0; // This is a private variable
#
#             function increment() { // This is a private function
#                 count++;
#                 console.log(count);
#             }
#
#             return {
#                 increment // Exposing the increment function to the outside
#             };
#         }
#
#         const counter = createCounter();
#         counter.increment(); // Output: 1
#         counter.increment(); // Output: 2
#         console.log(counter.count); // Output: undefined (count is private)
#     ```
#     - Explanation:
#         - In this example, `count` is a private variable that cannot be accessed directly from outside the `createCounter` function. The `increment` function is also private and can only be called through the object returned by `createCounter`.
#         - By using closures, we can create private variables and functions that are encapsulated within the factory function, allowing us to control access to them and protect the internal state of our objects.

# %% [markdown]
# #### IIFEs & the Module Pattern

# %% [markdown]
# - **Module Pattern** is a design pattern used to create modules in JavaScript. It allows us to encapsulate code and create private variables and functions while exposing only the necessary parts of the module to the outside world. This is often achieved using an Immediately Invoked Function Expression (IIFE).

# %% [markdown]
# - **IIEFs (Immediately Invoked Function Expressions)** are functions that are defined and immediately executed. They are often used to create a new scope and avoid polluting the global namespace.
# - Example:
#     ```javascript
#         (function() {
#             const privateVariable = "I am private";
#             console.log(privateVariable);
#         })();
#     ```
#     - Explanation:
#         - In this example, we define an anonymous function and immediately invoke it. This creates a new scope for the `privateVariable`, which is not accessible from outside the function. This pattern is useful for encapsulating code and preventing variables from leaking into the global scope.

# %% [markdown]
# ### Classes

# %% [markdown]
# #### Intro

# %% [markdown]
# - JS does not have traditional classes like other programming languages, but it has a class syntax that provides a more familiar way to create objects and handle inheritance. The class syntax is syntactic sugar over the existing prototype-based inheritance in JavaScript, making it easier to write and understand object-oriented code.
# - Example:
#     ```javascript
#         class Car {
#             constructor(make, model, year) {
#                 this.make = make;
#                 this.model = model;
#                 this.year = year;
#             }
#
#             getCarInfo() {
#                 return `${this.year} ${this.make} ${this.model}`;
#             }
#         }
#
#         const car1 = new Car("Volkswagen", "Golf", 2026);
#         console.log(car1.getCarInfo()); // Output: 2026 Volkswagen Golf
#     ```
#     - Explanation:
#         - In this example, we define a class `Car` with a constructor that initializes the properties of the car object and a method `getCarInfo` that returns a string with the car's information.
#         - We create an instance of the `Car` class using the `new` keyword, which allows us to call the constructor and initialize the object. The class syntax provides a clearer and more concise way to define objects and their behavior compared to using constructor functions and prototypes directly.

# %% [markdown]
# - **_Basic class syntax:_**
#     ```javascript
#         class ClassName {
#             constructor(parameters) {
#                 // initialization code
#             }
#
#             methodName() {
#                 // method code
#             }
#         }
#     ```
# - The `constructor` method is a special method for creating and initializing an object created with a class. It is called automatically when a new instance of the class is created using the `new` keyword. The `constructor` can take parameters to initialize the properties of the object.

# %% [markdown]
# - _Differences between an object constructor and a class:_
#     1. Syntax: Classes use a more concise and familiar syntax compared to constructor functions, making it easier to read and write object-oriented code.
#
#     2. Inheritance: Classes provide a built-in way to handle inheritance using the `extends` keyword, while constructor functions require manual setup of the prototype chain for inheritance.
#
#     3. Static Methods: Classes allow you to define static methods that are called on the class itself, rather than on instances of the class. Constructor functions do not have this feature.
#
#     4. Hoisting: Class declarations are not hoisted, meaning you cannot use a class before it is declared in the code. Constructor functions, on the other hand, are hoisted and can be used before their declaration.

# %% [markdown]
# - **Getters and Setters** are special methods in classes that allow you to define how to access and modify the properties of an object.
#     1. Getters are used to retrieve the value of a property, while
#
#     2. setters are used to set the value of a property.
#
# - Example:
#     ```javascript
#         class Car {
#             constructor(make, model, year) {
#                 this.make = make;
#                 this.model = model;
#                 this.year = year;
#             }
#
#             get carInfo() { // Getter
#                 return `${this.year} ${this.make} ${this.model}`;
#             }
#
#             set updateYear(newYear) { // Setter
#                 this.year = newYear;
#             }
#         }
#
#         const car1 = new Car("Volkswagen", "Golf", 2026);
#         console.log(car1.carInfo); // Output: 2026 Volkswagen Golf
#
#         car1.updateYear = 2027; // Using the setter to update the year
#         console.log(car1.carInfo); // Output: 2027 Volkswagen Golf
#     ```
#     - Explanation:
#         - In this example, we define a getter `carInfo` that returns a string with the car's information and a setter `updateYear` that allows us to update the year of the car.
#         - We can access the getter as if it were a property (`car1.carInfo`) and use the setter to update the year by assigning a new value to it (`car1.updateYear = 2027`). This provides a clean and intuitive way to manage object properties while encapsulating the logic for getting and setting values.

# %% [markdown]
# #### Inheritance with Classes

# %% [markdown]
# - **_Inheritance_** is a fundamental concept in object-oriented programming that allows a new class (called a `subclass` or `child class`) to inherit properties and methods from an existing class (called a `superclass` or `parent class`). In JavaScript, we can achieve inheritance using the `extends` keyword in class syntax.
#
# - Example:
#     ```javascript
#         class Vehicle {
#             constructor(type) {
#                 this.type = type;
#             }
#
#             getType() {
#                 return this.type;
#             }
#         }
#
#         class Car extends Vehicle {
#             constructor(make, model, year) {
#                 super("car"); // Call the parent class constructor
#                 this.make = make;
#                 this.model = model;
#                 this.year = year;
#             }
#         }
#         const car1 = new Car("Volkswagen", "Golf", 2026);
#         console.log(car1.getType()); // Output: car (inherited from Vehicle)
#     ```
#     - Explanation:
#         - In this example, we have a `Vehicle` class with a method `getType`. The `Car` class extends `Vehicle`, which means it inherits the properties and methods of `Vehicle`.
#         - The `super("car")` call in the `Car` constructor is used to call the constructor of the parent class (`Vehicle`) and initialize the `type` property.
#         - When we create an instance of `Car` and call `car1.getType()`, it successfully accesses the inherited method from the `Vehicle` class, demonstrating how inheritance works with classes in JavaScript.

# %% [markdown]
# #### Private Class Fields & Methods

# %% [markdown]
# - A private class field is a property that is only accessible within the class it is defined in. It is denoted by a `#` prefix before the field name. Private fields cannot be accessed or modified from outside the class, providing encapsulation and data hiding.
#
# - Example:
#     ```javascript
#         class Car {
#             #make; // Private field
#             #model; // Private field
#
#             constructor(make, model) {
#                 this.#make = make;
#                 this.#model = model;
#             }
#
#             getCarInfo() {
#                 return `${this.#make} ${this.#model}`;
#             }
#         }
#
#         const car1 = new Car("Volkswagen", "Golf");
#         console.log(car1.getCarInfo()); // Output: Volkswagen Golf
#         console.log(car1.#make); // Error: Private field '#make' must be declared in an enclosing class
#     ```
#     - Explanation:
#         - In this example, `#make` and `#model` are private fields that cannot be accessed from outside the `Car` class. The `getCarInfo` method can access these private fields because it is defined within the class.
#         - Attempting to access `car1.#make` from outside the class results in an error, demonstrating that the private fields are truly private and cannot be accessed or modified from outside the class. This feature allows for better encapsulation and data hiding in JavaScript classes.

# %% [markdown]
# - Private methods can also be defined in a similar way using the `#` prefix. They are only accessible within the class and cannot be called from outside the class.
#
# - Example:
#     ```javascript
#         class Car {
#             #make; // Private field
#             #model; // Private field
#
#             constructor(make, model) {
#                 this.#make = make;
#                 this.#model = model;
#             }
#
#             #getCarInfo() { // Private method
#                 return `${this.#make} ${this.#model}`;
#             }
#
#             publicGetCarInfo() { // Public method that calls the private method
#                 return this.#getCarInfo();
#             }
#         }
#
#         const car1 = new Car("Volkswagen", "Golf");
#         console.log(car1.publicGetCarInfo()); // Output: Volkswagen Golf
#         console.log(car1.#getCarInfo()); // Error: Private method '#getCarInfo' must be declared in an enclosing class
#     ```
#     - Explanation:
#         - In this example, `#getCarInfo` is a private method that can only be called from within the `Car` class. The `publicGetCarInfo` method is a public method that calls the private method to retrieve the car information.
#         - Attempting to call `car1.#getCarInfo()` from outside the class results in an error, demonstrating that private methods are also encapsulated and cannot be accessed from outside the class. This allows for better control over the internal behavior of the class while still providing a public interface for interacting with it.

# %% [markdown]
# #### Static Properties & Methods

# %% [markdown]
# - Static properties and methods are associated with the class itself rather than instances of the class. They can be accessed directly on the class without needing to create an instance. Static members are defined using the `static` keyword.
#
# - Example:
#     ```javascript
#         class Car {
#             static numberOfWheels = 4; // Static property
#
#             constructor(make, model) {
#                 this.make = make;
#                 this.model = model;
#             }
#
#             static getNumberOfWheels() { // Static method
#                 return Car.numberOfWheels;
#             }
#         }
#
#         console.log(Car.numberOfWheels); // Output: 4 (accessing static property)
#         console.log(Car.getNumberOfWheels()); // Output: 4 (calling static method)
#     ```
#     - Explanation:
#         - In this example, `numberOfWheels` is a static property that belongs to the `Car` class, and `getNumberOfWheels` is a static method that returns the value of the static property.
#         - We can access the static property and call the static method directly on the `Car` class without creating an instance. This is useful for properties and methods that are relevant to the class as a whole rather than individual instances.

# %% [markdown]
# ### Modules

# %% [markdown]
# - **Modules:** are a way to organize and encapsulate code in JavaScript. They allow you to break your code into smaller, reusable pieces, and control the visibility of variables and functions. Modules can be implemented using various patterns, such as the Module Pattern or ES6 modules. In simpler terms, modules help you keep your code organized and prevent naming conflicts by encapsulating functionality and exposing only what is necessary to the outside world.

# %% [markdown]
# #### Import & Export

# %% [markdown]
# - In Modules, we can use `export` to make variables, functions, or classes available for use in other files, and `import` to bring those exported members into another file.
# - Example:
#     ```javascript
#         // In mathUtils.js
#         export function add(a, b) {
#             return a + b;
#         }
#
#         export const PI = 3.14159;
#
#         // In main.js
#         import { add, PI } from './mathUtils.js';
#
#         console.log(add(2, 3)); // Output: 5
#         console.log(PI); // Output: 3.14159
#     ```
#     - Explanation:
#         - In this example, we have a module `mathUtils.js` that exports a function `add` and a constant `PI`. In another file `main.js`, we import these members using the `import` statement.
#         - This allows us to keep our code organized by separating functionality into different files while still being able to use the exported members across our application.

# %% [markdown]
# - There are 2 types of importing and exporting:
#     1. **Named Exports/Imports:** You can export multiple variables, functions, or classes from a module using named exports. When importing, you need to use the same names as the exported members. There are 2 ways to use `named` exports:
#         * Exporting/Importing as you declare:
#
#         ```javascript
#             export function add(a, b) {
#                 return a + b;
#             }
#
#             export const PI = 3.14159;
#         ```
#
#         ```javascript
#         //Importing
#             import { add, PI } from './mathUtils.js';
#         ```
#
#
#         * Exporting/Importing after you declare:
#         ```javascript
#             function add(a, b) {
#                 return a + b;
#             }
#
#             const PI = 3.14159;
#
#             export { add, PI };
#         ```
#
#         ```javascript
#         //importing
#             import { add, PI } from './mathUtils.js';
#         ```

# %% [markdown]
# 2. **Default Exports/Imports:** A module can have **_only one_** default export, which can be a variable, function, or class. When importing a default export, you can choose any name for it.
#     - Example:
#         ```javascript
#             // In mathUtils.js
#             export default function subtract(a, b) {
#                 return a - b;
#             }
#
#             // In main.js
#             import subtract from './mathUtils.js';
#
#             console.log(subtract(5, 2)); // Output: 3
#         ```
#         - Explanation:
#             - In this example, we have a default export of the `subtract` function in `mathUtils.js`. When we import it in `main.js`, we can choose any name for the imported function (in this case, we also called it `subtract` for clarity).
#             - Default exports are useful when you want to export a single main functionality from a module, while named exports are better for exporting multiple related functionalities.
#
#     - Another example of default export:
#         ```javascript
#             // In car.js
#             export default class Car {
#                 constructor(make, model) {
#                     this.make = make;
#                     this.model = model;
#                 }
#             }
#
#             // In main.js
#             import Car from './car.js';
#
#             const myCar = new Car("Volkswagen", "Golf");
#             console.log(myCar); // Output: Car { make: 'Volkswagen', model: 'Golf' }
#         ```
#         - Explanation:
#             - In this example, we have a default export of the `Car` class in `car.js`. When we import it in `main.js`, we can create an instance of the `Car` class and use it as needed. This demonstrates how default exports can be used to export classes or other main functionalities from a module.

# %% [markdown]
# - You can combine named and default exports in the same module, but you need to be careful with the syntax when importing them.
#     - Example:
#         ```javascript
#             // In mathUtils.js
#             export function add(a, b) {
#                 return a + b;
#             }
#
#             export const PI = 3.14159;
#
#             export default function subtract(a, b) {
#                 return a - b;
#             }
#
#             // In main.js
#             import subtract, { add, PI } from './mathUtils.js';
#
#             console.log(add(2, 3)); // Output: 5
#             console.log(PI); // Output: 3.14159
#             console.log(subtract(5, 2)); // Output: 3
#         ```
#         - Explanation:
#             - In this example, we have both named exports (`add` and `PI`) and a default export (`subtract`) in the `mathUtils.js` module. When importing, we first import the default export (which can be named anything) and then the named exports using their specific names. This allows us to use all the exported members from the module in our `main.js` file.

# %% [markdown]
# #### Entry Points

# %% [markdown]
# - When we use ESM (ECMAScript Modules) instead of adding every JavaScript file to our HTML in order, we only need to link a single file - the **_entry point_**.
# - The `entry point` is the main JavaScript file that serves as the starting point for our application. It is responsible for importing other modules and initializing the application. By using an entry point, we can manage our code more efficiently and keep our HTML cleaner, as we only need to include one script tag that points to the entry point file.
#
# - We mostly use the `index.js` file as the entry point, but it can be named anything. The important thing is that it serves as the main file that imports other modules (dependent on other files) and starts the application.
#
# - Declaration:
#     ```html
#         <script type="module" src="index.js"></script>
#     ```
#     - Explanation:
#         - In this example, we have an `index.js` file that serves as the entry point for our application. We declare it in our HTML using a `<script>` tag with the `type="module"` attribute, which tells the browser that this script is an ES6 module.
#         - The `index.js` file can then import other modules and initialize the application. This approach allows us to keep our HTML clean and organized, as we only need to include one script tag for the entry point, and it also helps us manage our code more efficiently by breaking it into smaller, reusable modules.

# %% [markdown]
# - **_Dependency Graph:_** When we have multiple modules that depend on each other, we can visualize the relationships between them using a dependency graph.
#
# - A dependency graph is a directed graph that shows how modules are connected based on their import and export relationships. Each node in the graph represents a module, and each directed edge represents an import statement from one module to another.
#
# - Example:
#     ```
#         index.js
#         ├── mathUtils.js
#         │   ├── add()
#         │   └── PI
#         └── car.js
#             └── Car class
#     ```
#     - Explanation:
#         - In this example, we have an `index.js` file that serves as the entry point for our application. It imports two modules: `mathUtils.js` and `car.js`.
#         - The `mathUtils.js` module exports a function `add()` and a constant `PI`, while the `car.js` module exports a `Car` class. The dependency graph shows how these modules are connected, with `index.js` depending on both `mathUtils.js` and `car.js`. This visualization helps us understand the structure of our code and how different modules interact with each other.

# %% [markdown]
# #### Common JS (CJS)

# %% [markdown]
# - CJS (CommonJS) is a module system used in Node.js for organizing and structuring code. It allows developers to create reusable modules and manage dependencies in a modular way. In CommonJS, we use `require` to import modules and `module.exports` to export them.
# - Example:
#     ```javascript
#         // In mathUtils.js
#         function add(a, b) {
#             return a + b;
#         }
#
#         const PI = 3.14159;
#
#         module.exports = { add, PI };
#
#         // In main.js
#         const { add, PI } = require('./mathUtils.js');
#
#         console.log(add(2, 3)); // Output: 5
#         console.log(PI); // Output: 3.14159
#     ```
#     - Explanation:
#         - In this example, we define a module `mathUtils.js` that exports a function `add` and a constant `PI` using `module.exports`. In another file `main.js`, we import these members using the `require` function.
#         - CommonJS is primarily used in Node.js environments and is not natively supported in browsers. However, tools like Browserify or Webpack can be used to bundle CommonJS modules for use in the browser.

# %% [markdown]
# ### npm

# %% [markdown]
# - **npm:** is a package manager for JavaScript that allows developers to easily share and reuse code. npm provides a vast ecosystem of open-source libraries and tools that can be easily installed and managed in your projects. With npm, you can install packages from the npm registry, manage dependencies, and run scripts to automate tasks in your development workflow.
#
# - In simpler terms, `npm` is a tool that helps you find and use code written by other developers, making it easier to build your applications without having to reinvent the wheel.
#
# - To use npm, you need to have `Node.js` installed on your machine, as npm comes bundled with Node.js. Once you have Node.js installed, you can use npm to manage your project dependencies and run scripts.

# %% [markdown]
# #### package.json

# %% [markdown]
# - `package.json` is a file that contains metadata about your project and its dependencies. It is used by npm to manage your project's dependencies, scripts, and other configurations. The `package.json` file is typically located in the root directory of your project. It includes information such as the project name, version, description, author, license, and most importantly, the dependencies and scripts.
#
# - It’s a JSON _(JavaScript Object Notation)_ file containing information about our project, such as its name or any dependencies and their version numbers. npm can read this file and do things such as install all of the listed dependencies with the correct versions, and running commands that you’ve set as an npm script

# %% [markdown]
# - Example:
#     ```json
#         {
#             "name": "my-project",
#             "version": "1.0.0",
#             "description": "A sample project using npm",
#             "main": "index.js",
#             "scripts": {
#                 "start": "node index.js",
#                 "test": "echo \"Error: no test specified\" && exit 1"
#             },
#             "author": "Your Name",
#             "license": "ISC",
#             "dependencies": {
#                 "express": "^4.17.1"
#             }
#         }
#     ```
#     - Explanation:
#         - In this example, we have a `package.json` file that defines a project with the name `my-project`, version `1.0.0`, and a description. It specifies `index.js` as the main entry point of the application.
#
#         - The `scripts` section defines two scripts: `start`, which runs the application using Node.js, and `test`, which is a placeholder for running tests.
#
#         - The `dependencies` section lists the packages that the project depends on, in this case, the `express` package with a version of `^4.17.1`. This means that when we run `npm install`, npm will install the specified version of Express and its dependencies.
#
#         - The `license` field specifies the license under which the project is released, and the `author` field provides information about the creator of the project. Overall, the `package.json` file serves as a central configuration file for managing the project's dependencies and scripts.

# %% [markdown]
# - Read more here: [the package.json file](https://docs.npmjs.com/creating-a-package-json-file)

# %% [markdown]
# ##### Installing packages with npm

# %% [markdown]
# - npm is used to install packages _(dependencies, or in simpler terms, libraries)_ from the npm registry, which is a large collection of open-source libraries and tools. You can install packages globally or locally in your project.
#
# - To install a package locally in your project, you can use the following command:
#     ```bash
#         npm install package-name
#     ```
#     - This will install the specified package and add it to the `dependencies` section of your `package.json` file.

# %% [markdown]
# - Read more here: [installing packages with npm](https://docs.npmjs.com/downloading-and-installing-packages-locally)

# %% [markdown]
# ### Webpack

# %% [markdown]
# 1. [Webpack concepts](https://webpack.js.org/concepts/)
#
# 2. [Webpack Asset Management Guide](https://webpack.js.org/guides/asset-management/)

# %% [markdown]
# #### Bundling

# %% [markdown]
# - **Bundling:** is the process of taking multiple JavaScript files and combining them into a single file (or a few files) that can be included in an HTML page. This is important for optimizing the loading of web applications, as it reduces the number of HTTP requests needed to load all the necessary JavaScript files.
#
# - Bundling also allows you to use modern JavaScript features and modules in your code, as the bundler will take care of resolving dependencies and ensuring that the code runs correctly in the browser.

# %% [markdown]
# - We provide an `entry point` (the main JavaScript file that serves as the starting point for our application) to the bundler, and it will analyze the dependencies of that file and include all the necessary modules in the final bundle.
#
# - Example:
#     ```javascript
#         // index.js (entry point)
#         import { add } from './mathUtils.js';
#         console.log(add(2, 3)); // Output: 5
#
#         // mathUtils.js
#         export function add(a, b) {
#             return a + b;
#         }
#     ```
#     - Explanation:
#         - In this example, we have an `index.js` file that serves as the entry point for our application. It imports the `add` function from `mathUtils.js`.
#
#         - When we run the `bundler` (e.g., **Webpack**), it will analyze the dependencies of `index.js`, find that it depends on `mathUtils.js`, and include both files in the final bundle. This allows us to write modular code using ES6 modules while still being able to run it in the browser without worrying about module support or multiple script tags.

# %% [markdown]
# #### Webpack

# %% [markdown]
# - **Webpack:** is a popular module bundler for JavaScript applications. It takes your JavaScript files and their dependencies, processes them, and generates a single bundle (or multiple bundles) that can be included in your HTML page. Webpack also provides features like code splitting, hot module replacement, and support for various loaders and plugins to enhance the development experience.

# %% [markdown]
# ##### Bundling JS using Webpack

# %% [markdown]
# 1. **_Step 1: Install Webpack and Webpack CLI as development dependencies in your project:_**
#     ```bash
#         npm install --save-dev webpack webpack-cli
#     ```
#
#     - This command installs Webpack and its command-line interface (CLI) as development dependencies, which means they are only needed during the development process and will not be included in the production build.
#
#     - It also creates a `node_modules` directory in your project where the Webpack packages are installed, and it adds an entry for Webpack in the `devDependencies` section of your `package.json` file.
#
#     - It also creates a `package-lock.json` file if it doesn't already exist, which locks the versions of the installed packages to ensure consistent installations across different environments.

# %% [markdown]
# * **src & dist:**
#     - `src` (source) is the directory where you typically place your original JavaScript files and other assets that you want to bundle. This is where you write your code and organize it in a modular way.
#
#     - `dist` (distribution) is the directory where the bundled output from Webpack is generated. This is the directory that you would include in your HTML page to load the bundled JavaScript file(s). The `dist` directory is usually specified in the Webpack configuration file, and it is where Webpack will output the final bundled files after processing your source code from the `src` directory.
#
#     - In simpler terms, `src` is where you write your code, and `dist` is where the bundled version of your code is generated for use in production. That is, you `deploy` the contents of the `dist` directory to your web server to make your application available to users.
#
#     - If you clone or fork a project that uses Webpack, yyou only need to run `npm install` to install the dependencies, and then you can run the Webpack build process to generate the bundled files in the `dist` directory. You do not need to manually create the `dist` directory, as Webpack will handle that for you when it generates the output.

# %% [markdown]
# 2. **_Step 2: Create a `src` directory and add your JavaScript files there._**
# - For example, create an `src` with 2 js files inside: `index.js` and `greeting.js`:
#
#     - `src/index.js`:
#         ```javascript
#             import { greeting } from "./greeting.js";
#             console.log(greeting);
#
#         ```
#
#     - `src/greeting.js`:
#         ```javascript
#             export const greeting = "Hello, Odinite!";
#         ```
#     - Explanation:
#         - In this step, we create a `src` directory where we place our original JavaScript files. We have an `index.js` file that serves as the entry point for our application, and it imports (depends on) a `greeting` constant from `greeting.js`. The `greeting.js` file exports a constant string that we want to use in our application.

# %% [markdown]
# 3. **_Step 3: Create a `webpack.config.js` file in the root directory of your project to configure Webpack:_**
#     ```javascript
#         // webpack.config.js
#             import path from "node:path"; // Importing the path module to resolve file paths
#
#             export default {
#                 mode: "development", // Setting the mode to development for better debugging and readable output
#
#                 entry: "./src/index.js", // Specifying the entry point for the application
#
#                 output: {
#                     filename: "main.js", // The name of the output bundle file
#
#                     path: path.resolve(import.meta.dirname, "dist"), // Resolving the output path to the 'dist' directory
#
#                     clean: true, // Clean the output directory before each build to remove old files
#                 },
#             };
#     ```
#     - Explanation:
#         - In this step, we create a `webpack.config.js` file to configure Webpack. We set the `mode` to `development` for better debugging and readable output during development.
#
#         - We specify the `entry` point of our application as `./src/index.js`, which is the main JavaScript file that serves as the starting point for our application.
#
#         - In the `output` section, we define the name of the output bundle file as `main.js` and resolve the output path to the `dist` directory using the `path` module. The `clean: true` option ensures that the output directory is cleaned before each build, removing any old files that may be present.

# %% [markdown]
# 4. **_Step 4: Run the Webpack build process to generate the bundled files in the `dist` directory:_**
#
#     ```bash
#         npx webpack
#     ```
#     - Explanation:
#         - In this step, we run the Webpack build process using the command `npx webpack`. This command tells Webpack to read the configuration from `webpack.config.js`, process the files starting from the specified entry point (`./src/index.js`), and generate the bundled output in the `dist` directory as defined in the configuration.
#
#         - After running this command, you should see a `main.js` file in the `dist` directory, which is the bundled version of your application that can be included in your HTML page for production use.
#
# - If you run `node dist/main.js`, you will see the output of the bundled code in the terminal, which should log "Hello, Odinite!" to the console, demonstrating that the bundling process has successfully combined the code from `index.js` and `greeting.js` into a single file.

# %% [markdown]
# 5. **_Step 5: Include the bundled file in your HTML page:_**
#
#     ```html
#         <!DOCTYPE html>
#         <html lang="en">
#         <head>
#             <meta charset="UTF-8">
#             <meta name="viewport" content="width=device-width, initial-scale=1.0">
#             <title>Webpack Example</title>
#         </head>
#         <body>
#             <script src="./dist/main.js"></script> <!-- Including the bundled JavaScript file -->
#         </body>
#         </html>
#     ```
#     - Explanation:
#         - In this final step, we include the bundled JavaScript file (`main.js`) in our HTML page using a `<script>` tag. This allows us to load the bundled code into the browser and run our application.
#
#         - The `src` attribute of the `<script>` tag points to the location of the bundled file in the `dist` directory. When the browser loads this HTML page, it will execute the code in `main.js`, which contains all the necessary JavaScript for our application as processed by Webpack.

# %% [markdown]
# ##### Bundling HTML using Webpack

# %% [markdown]
# 1. **_Step 1: Install Webpack and Webpack CLI as development dependencies in your project:_**
#
#     ```bash
#         npm install --save-dev webpack webpack-cli
#     ```

# %% [markdown]
# 2. **_Step 2: Install the `html-webpack-plugin` to handle HTML files in Webpack:_**
#
#     ```bash
#         npm install --save-dev html-webpack-plugin
#     ```
#
#     - This command installs the `html-webpack-plugin`, which is a plugin for Webpack that simplifies the creation of HTML files to serve your bundled JavaScript. **It automatically injects the bundled JavaScript files into the HTML file, making it easier to manage your HTML and JavaScript together. Therefore, no need to manually include the bundled file in your HTML.**
#
#     - It also adds an entry for `html-webpack-plugin` in the `devDependencies` section of your `package.json` file.
#
#     - It also creates a `package-lock.json` file if it doesn't already exist, which locks the versions of the installed packages to ensure consistent installations across different environments.

# %% [markdown]
# 3. **_Step 3: Create a `template.html` file in the `src` directory that will serve as the template for your HTML file:_**
# - (you can name this file anything you like)
#
#     ```html
#         <!-- src/template.html -->
#         <!DOCTYPE html>
#         <html lang="en">
#         <head>
#             <meta charset="UTF-8">
#             <meta name="viewport" content="width=device-width, initial-scale=1.0">
#             <title>Webpack HTML Example</title>
#         </head>
#         <body>
#             <h1>Welcome to Webpack!</h1>
#         </body>
#         </html>
#     ```
#     - Explanation:
#         - In this step, we create a `template.html` file in the `src` directory that serves as the template for our HTML file. This template will be used by the `html-webpack-plugin` to generate the final HTML file that includes the bundled JavaScript.

# %% [markdown]
# 4. **_Step 4: Create a `webpack.config.js` file in the root directory of your project to configure Webpack and use the `html-webpack-plugin`:_**
#
#     ```javascript
#         // webpack.config.js
#         import path from "node:path";
#         import HtmlWebpackPlugin from "html-webpack-plugin";
#
#         export default {
#             mode: "development",
#             entry: "./src/index.js",
#             output: {
#                 filename: "main.js",
#                 path: path.resolve(import.meta.dirname, "dist"),
#                 clean: true,
#             },
#
#             plugins: [
#                 new HtmlWebpackPlugin({
#                 template: "./src/template.html",
#                 }),
#             ],
#         };
#     ```
#     - Explanation:
#         - In this step, we configure Webpack to use the `html-webpack-plugin`. We import the plugin at the top of the configuration file and then add it to the `plugins` array in the Webpack configuration.
#
#         - The `HtmlWebpackPlugin` is instantiated with an options object that specifies the `template` property, which points to our `template.html` file. This tells the plugin to use our template as the basis for generating the final HTML file.
#
#         - When we run the Webpack build process, the `html-webpack-plugin` will take our `template.html`, inject the bundled JavaScript file (`main.js`) into it, and output a new HTML file in the `dist` directory that can be served to users. This allows us to manage our HTML and JavaScript together without having to manually include script tags in our HTML.

# %% [markdown]
# - If we run `npx webpack`, Webpack will generate a new HTML file in the `dist` directory that includes the bundled JavaScript file. The generated HTML file will be based on our `template.html` and will have a script tag automatically injected to include the bundled JavaScript. This allows us to easily manage our HTML and JavaScript together without having to manually update our HTML file every time we change our JavaScript code.

# %% [markdown]
# ##### Loading CSS with Webpack

# %% [markdown]
# - For CSS, we need 2 packages instead of 1:
#     1. `style-loader`: Injects CSS into the DOM by adding a `<style>` tag. In simpler terms, it takes the CSS code and adds it to the HTML document so that the styles are applied to the page.
#
#     2. `css-loader`: Interprets `@import` and `url()` like `import/require()` and resolves them. In simpler terms, it allows you to import CSS files into your JavaScript files and handles the dependencies between them.
#
# - The `css-loader` will read any CSS files we import in a JS file and store the result in a string. The `style-loader` then takes that string and actually adds the JS code that will apply those styles to the page. Thus the need for both.

# %% [markdown]
# 1. **_Step 1: Install the necessary loaders for handling CSS files in Webpack:_**
#
#     ```bash
#         npm install --save-dev style-loader css-loader
#     ```
#
#     - This command installs both `style-loader` and `css-loader` as development dependencies in your project. These loaders are essential for processing CSS files when bundling with Webpack.
#
#     - It also adds entries for both loaders in the `devDependencies` section of your `package.json` file.
#
#     - It also creates a `package-lock.json` file if it doesn't already exist, which locks the versions of the installed packages to ensure consistent installations across different environments.

# %% [markdown]
# 2. **_Step 2: Add these loaders to your Webpack configuration to handle CSS files:_**
# - Since these aren't plugins but loaders, they go in a separate section:
#
#     ```javascript
#         // webpack.config.js
#         import path from "node:path";
#         import HtmlWebpackPlugin from "html-webpack-plugin";
#
#         export default {
#             mode: "development",
#             entry: "./src/index.js",
#             output: {
#                 filename: "main.js",
#                 path: path.resolve(import.meta.dirname, "dist"),
#                 clean: true,
#             },
#             plugins: [
#                 new HtmlWebpackPlugin({
#                 template: "./src/template.html",
#                 }),
#             ],
#             module: {
#                 rules: [
#                 {
#                     test: /\.css$/i,
#                     use: ["style-loader", "css-loader"],
#                 },
#                 ],
#             },
#         };
#     ```
#
#     - Explanation:
#         - In this step, we update our Webpack configuration to include rules for handling CSS files. We add a `module` section with a `rules` array that specifies how to process files that match the `.css` extension.
#
#         - The rule uses a regular expression (`test: /\.css$/i`) to identify CSS files and specifies that they should be processed using both `style-loader` and `css-loader`. The order of the loaders is important: `css-loader` processes the CSS file first, and then `style-loader` injects the styles into the DOM.
#
#         - With this configuration, when we import a CSS file in our JavaScript code, Webpack will use these loaders to handle the CSS and ensure that the styles are applied correctly in the browser.
#
# - **_NB: Loader order matters for CSS!_**
#     * _Notice how we put `css-loader` at the end of the array. We must set this order and not the reverse._
#
#     * _Webpack will run the loaders starting at the end, so we want it to read the CSS file into a string with `css-loader` **first**, then use `style-loader` to inject the JavaScript that applies the CSS in that string to the page. It wouldn’t work the same the other way round._

# %% [markdown]
# 3. **_Step 3: Import the CSS file in your JavaScript entry point (e.g., `index.js`):_**
#
#     ```javascript
#         // src/index.js
#         import "./styles.css"; // Importing the CSS file
#
#         console.log("Hello, Webpack with CSS!");
#     ```
#
#     - Explanation:
#         - In this step, we import the CSS file (`styles.css`) into our JavaScript entry point (`index.js`). This tells Webpack to process the CSS file using the loaders we configured in the previous step.
#
#         - When we run the Webpack build process, it will use `css-loader` to read the contents of `styles.css` and then use `style-loader` to inject those styles into the DOM. This allows us to manage our styles directly from our JavaScript files and ensures that they are included in the final bundled output.

# %% [markdown]
# 4. **_Step 4: Bundle everything with webpack:_**
#
#     ```bash
#         npx webpack
#     ```
#
#     - Explanation:
#         - In this final step, we run the Webpack build process using the command `npx webpack`. This will process all our JavaScript and CSS files according to the configuration we set up, and generate the bundled output in the `dist` directory.
#
#         - After running this command, you should see a new HTML file in the `dist` directory that includes the bundled JavaScript and has the styles from `styles.css` applied to it. This demonstrates that Webpack has successfully processed both our JavaScript and CSS files and generated a complete bundle for our application.

# %% [markdown]
# ##### What about link tags?

# %% [markdown]
# - Should we still link our CSS files in the HTML with `<link>` tags when using Webpack to bundle our CSS?
#     - **_No, when using Webpack to bundle your CSS, you do not need to link your CSS files in the HTML with `<link>` tags. Instead, you should import your CSS files directly into your JavaScript entry point (e.g., `index.js`) using an import statement like `import "./styles.css";`._**

# %% [markdown]
# ##### Loading Images

# %% [markdown]
# - Local image files also require extra configuration since they are not JS files.
#
# - There are 3 different ways to deal with local image files:
#
#     1. **_Image files used in our CSS inside `url()`:_**
#         * The `css-loader` will automatically handle image files that are referenced in our CSS files using `url()`. When we import a CSS file that contains `url()` references to images, the `css-loader` will process those references and include the images in the bundle. This means that we can simply reference our images in our CSS files, and Webpack will take care of bundling them correctly. Thus, nothing extra to do.
#
#         * Example:
#             ```css
#                 /* styles.css */
#                 .background {
#                     background-image: url('./images/background.jpg');
#                 }
#             ```
#             - Explanation:
#                 - In this example, we have a CSS file that references an image using `url()`. When we import this CSS file in our JavaScript entry point, the `css-loader` will automatically process the image reference and include it in the bundle. This allows us to manage our images directly from our CSS files without needing to do any additional configuration for handling images in Webpack.
#
#     2. **_Image files we reference in out HTML template, e.g. as the src of an `<img>`:_**
#         * For images that we reference directly in our HTML template (e.g., using `<img src="./images/logo.png">`), we need to use the `html-loader` to process those image references. The `html-loader` will analyze the HTML file, find any image references, and include those images in the bundle.
#
#         * Without this, a `src` like `./odin.png` would just be a bit of text that will no longer reference the correct file once we run Webpack to build into dist. Let’s install it:
#
#         * To set this up, we need to install the `html-loader` and configure it in our Webpack configuration file.
#
#         * Example:
#             ```bash
#                 npm install --save-dev html-loader
#             ```
#
#             - Then, add the following object to the `module.rules` array within `webpack.config.js`:
#
#             ```javascript
#                 // webpack.config.js
#                 {
#                     test: /\.html$/i,
#                     use: ["html-loader"],
#                 }
#             ```
#             - Explanation:
#                 - In this example, we install the `html-loader` and configure it in our Webpack configuration file to handle HTML files. The `html-loader` will process any HTML files that we use as templates (e.g., `template.html`) and will analyze the content for any image references (like `<img src="./images/logo.png">`).
#
#                 - When we run the Webpack build process, the `html-loader` will find these image references in our HTML template and include those images in the bundle. This allows us to manage our images directly from our HTML files without needing to do any additional configuration for handling images in Webpack.
#
#
#     3. **_Images we use in our JS, where we will need to import the files:_**
#         - If we need to use a local image file in our JavaScript (such as when manipulating the DOM to create or edit `img` elements and set their `src` attribute), we need to import the images into our JavaScript module. Since images aren’t JavaScript, we need to tell Webpack that these files will be assets by adding an `asset/resource` rule. No need to install anything here. Just add the following object to the `module.rules` array within `webpack.config.js`:
#
#         ```javascript
#             // webpack.config.js
#             {
#                 test: /\.(png|svg|jpg|jpeg|gif)$/i,
#                 type: "asset/resource",
#             }
#         ```
#         - Explanation:
#             - In this example, we add a rule to our Webpack configuration to handle image files that we want to use in our JavaScript code. The rule uses a regular expression to match common image file extensions (like `.png`, `.jpg`, etc.) and specifies that these files should be treated as resources using `type: "asset/resource"`.
#
#             - When we import an image file in our JavaScript code (e.g., `import logo from './images/logo.png';`), Webpack will process the image file according to this rule and include it in the bundle. This allows us to manage our images directly from our JavaScript files and ensures that they are included correctly in the final output when we run the Webpack build process.
#
#             - _**PS**: You can always edit the regex in the test property to remove any file extensions you don’t need or add any extensions you do need. _

# %% [markdown]
# - Then, in whatever JavaScript module we want to use that image in, we just have to default import it.
#
# ```javascript
#     // src/index.js
#     import odinImage from "./odin.png";
#
#     const image = document.createElement("img");
#     image.src = odinImage;
#
#     document.body.appendChild(image);
# ```
#
# - Explanation:
#     - In this example, we import an image file (`odin.png`) into our JavaScript module using a default import. The imported value (`odinImage`) will be a string that represents the path to the image file in the bundled output.
#
#     - We then create a new `img` element using `document.createElement("img")`, set its `src` attribute to the imported image path, and append it to the body of the document. This allows us to dynamically add images to our web page using JavaScript while ensuring that the images are correctly processed and included in the Webpack bundle.

# %% [markdown]
# - Our final `webpack.config.js` file should look like this:
#
# ```javascript
#     // webpack.config.js
#     import path from "node:path";
#     import HtmlWebpackPlugin from "html-webpack-plugin";
#
#     export default {
#         mode: "development",
#         entry: "./src/index.js",
#         output: {
#             filename: "main.js",
#             path: path.resolve(import.meta.dirname, "dist"),
#             clean: true,
#         },
#         plugins: [
#             new HtmlWebpackPlugin({
#             template: "./src/template.html",
#             }),
#         ],
#         module: {
#             rules: [
#             {
#                 test: /\.css$/i,
#                 use: ["style-loader", "css-loader"],
#             },
#             {
#                 test: /\.html$/i,
#                 use: ["html-loader"],
#             },
#             {
#                 test: /\.(png|svg|jpg|jpeg|gif)$/i,
#                 type: "asset/resource",
#             },
#             ],
#         },
#     };
# ```

# %% [markdown]
# - You might notice that when images are included when bundling, the output image file in `dist` has a different file name (it will likely be some jumble of numbers and letters). By default, Webpack gives your bundled image files a new name by hashing their contents. You do not need to know how this works, nor do you need to dig into the details of why, nor how to change it. You just need to be aware that this is expected behavior (it’s to do with preventing issues with the browser cache and matching file names).

# %% [markdown]
# ##### Summary of Webpack:

# %% [markdown]
# - **_You only need to configure what you need_**
#     * You may not need everything we’ve mentioned. If your project does not have images with local file path sources in your HTML template, you do not need `html-loader` set up. If you aren’t using any local images in your JavaScript, you won’t need the image `asset/resource` rule set up.
#
#     * Similarly, in the future, you may end up working with things that need a special loader or plugin, such as custom fonts or preprocessors. You can always use Google or reference Webpack’s documentation for instructions on what you’d need when that time comes.

# %% [markdown]
# #### Webpack dev server

# %% [markdown]
# - The `webpack-dev-server` is a development server that provides live reloading and hot module replacement (HMR) for your Webpack projects. It allows you to serve your bundled application locally and automatically refresh the browser whenever you make changes to your code, providing a faster and more efficient development experience.
#
# - It works the same as the `Live Server` extension in VS Code, but it’s built specifically for Webpack projects and offers additional features like HMR, which allows you to update modules in the browser without a full page reload.
#
# - It ensures you don't run `npx webpack` every time you make a change to your code. Instead, it watches for changes and automatically rebuilds and refreshes the browser for you.

# %% [markdown]
# 1. **_Step 1: Install the `webpack-dev-server` as a development dependency in your project:_**
#
#     ```bash
#         npm install --save-dev webpack-dev-server
#     ```
#
#     - This command installs the `webpack-dev-server` package as a development dependency in your project. The `webpack-dev-server` provides a local development server with live reloading and hot module replacement features.
#
#     - It also adds an entry for `webpack-dev-server` in the `devDependencies` section of your `package.json` file.
#
#     - It also creates a `package-lock.json` file if it doesn't already exist, which locks the versions of the installed packages to ensure consistent installations across different environments.

# %% [markdown]
# - We can also use `source map`s with the dev server to make debugging easier. Source maps allow you to see the original source code in the browser's developer tools, even though the code has been bundled and minified by Webpack. To enable source maps, you can add the `devtool` property to your Webpack configuration:
#
# ```javascript
#     // webpack.config.js
#     export default {
#         // ... other configuration options ...
#         devtool: "inline-source-map", // Enable source maps for easier debugging
#         //or
#         devtool: "eval-source-map", // Another option for source maps. This option is faster for development but may not provide as detailed source maps as "inline-source-map".
#     };
# ```

# %% [markdown]
# 2. **_Step 2: Add these properties to the `webpack.config.js` file to configure the development server:_**
#
#     ```javascript
#         // webpack.config.js
#         import path from "node:path";
#         import HtmlWebpackPlugin from "html-webpack-plugin";
#
#         export default {
#             mode: "development",
#             entry: "./src/index.js",
#             output: {
#                 filename: "main.js",
#                 path: path.resolve(import.meta.dirname, "dist"),
#                 clean: true,
#             },
#             devtool: "eval-source-map",
#             devServer: {
#                 watchFiles: ["./src/template.html"],
#             },
#             plugins: [
#                 new HtmlWebpackPlugin({
#                 template: "./src/template.html",
#                 }),
#             ],
#             module: {
#                 rules: [
#                 {
#                     test: /\.css$/i,
#                     use: ["style-loader", "css-loader"],
#                 },
#                 {
#                     test: /\.html$/i,
#                     use: ["html-loader"],
#                 },
#                 {
#                     test: /\.(png|svg|jpg|jpeg|gif)$/i,
#                     type: "asset/resource",
#                 },
#                 ],
#             },
#         };

# %% [markdown]
# 3. Step 3: Run the development server using the following command:
#
#     ```bash
#         npx webpack serve
#     ```
#
#     - Explanation:
#         - In this step, we run the Webpack development server using the command `npx webpack serve`. This command starts the development server and serves our bundled application locally.
#
#         - The `devServer` configuration in our Webpack config specifies that the server should watch for changes to the `template.html` file. This means that if we make any changes to our HTML template, the development server will automatically rebuild the bundle and refresh the browser to reflect those changes.
#
#         - With the development server running, we can make changes to our source code (JavaScript, CSS, HTML) and see those changes reflected in real-time in the browser without needing to manually refresh or rerun the build process. This provides a much faster and more efficient development experience.
#
# - Our site will then be available at `http://localhost:8080` (or another port if 8080 is already in use). Whenever we make changes to our source files, the development server will automatically rebuild the bundle and refresh the browser to show the latest changes. This allows us to see our updates in real-time without needing to manually refresh the page or rerun the build process.

# %% [markdown]
# **_NB: Restart the dev server upon config changes_**
# - _Note that the webpack-dev-server only reads your webpack configuration when you start it. If you change the webpack config file while the dev server is running, it will not reflect those config changes. Use Ctrl + C in the terminal to kill it then rerun npx webpack serve to apply the new config._

# %% [markdown]
# ### Revisiting Webpack

# %% [markdown]
# #### npm scripts

# %% [markdown]
# - Read more: [npm scripts](https://dyte.io/blog/package-json-scripts/)

# %% [markdown]
# - We can write `npm scripts` in the `package.json` file to create custom commands that we can run using `npm run <script-name>`. This allows us to simplify our workflow by creating shortcuts for common tasks, such as starting the development server or building the project for production.
#
# - The basic syntax for defining an npm script is as follows:
#
#     ```json
#         {
#             // ... other package.json stuff
#             "scripts": {
#                 "build": "webpack",
#                 "start": "webpack serve",
#                 "deploy": "git subtree push --prefix dist origin gh-pages"
#             },
#             // ... other package.json stuff
#         }
#     ```
#
#     // To run the script, use the following command in the terminal:
#     ```bash
#         npm run build
#         npm run start
#         npm run deploy
#     ```
#
# - Example:
#     ```json
#         // package.json
#         {
#             "name": "webpack-example",
#             "version": "1.0.0",
#             "description": "",
#             "main": "index.js",
#             "scripts": {
#                 "start": "webpack serve --open", // Start the development server and open the browser
#                 "build": "webpack --mode production" // Build the project for production
#             },
#             "devDependencies": {
#                 // ... your dev dependencies ...
#             },
#             "dependencies": {
#                 // ... your dependencies ...
#             }
#         }
#     ```
#     - Explanation:
#         - In this example, we define two npm scripts in our `package.json` file: `start` and `build`. The `start` script runs the Webpack development server and automatically opens the browser, while the `build` script builds the project for production.
#
#         - By using these npm scripts, we can simply run `npm run start` to start our development server or `npm run build` to create a production build of our application without needing to remember the specific Webpack commands. This makes our workflow more efficient and easier to manage.

# %% [markdown]
# #### webpack modes

# %% [markdown]
# - Read more: [webpack modes](https://webpack.js.org/guides/production/)

# %% [markdown]
# - There are 2 webpack modes:
#     1. **_Development mode:_** This mode is optimized for development and provides features like better debugging, more readable output, and faster build times. It does not minify the code, which makes it easier to read and debug.
#
#     2. **_Production mode:_** This mode is optimized for production and focuses on performance and smaller bundle sizes. It minifies the code, removes unnecessary whitespace, and performs other optimizations to reduce the size of the output bundle.

# %% [markdown]
# - To change the mode, you can either set the `mode` property in your `webpack.config.js` file or use the `--mode` flag when running Webpack from the command line.
#
#     - Example using `webpack.config.js`:
#         ```javascript
#             // webpack.config.js
#             export default {
#                 mode: "production", // Set the mode to production for optimized builds
#                 // ... other configuration options ...
#             };
#         ```
#
#     - Example using command line:
#         ```bash
#             npx webpack --mode production
#         ```

# %% [markdown]
# - To save you from having to manually edit your configuration file every time you wish to switch modes, such as before bundling into `dist` or before going back to use your dev server, you can have two different configuration files (e.g.` webpack.dev.js` and `webpack.prod.js`), and then have your build and start npm scripts specify which configuration files to use (omitting the `--config` option makes Webpack search for `webpack.config.js` by default):
#
# - Example:
#     ```json
#         {
#             "build": "webpack --config webpack.prod.js", // Build the project using the production configuration
#
#             "start": "webpack serve --config webpack.dev.js" // Start the development server using the development configuration
#         }
#     ```

# %% [markdown]
# ##### Webpack-merge

# %% [markdown]
# - Read more: [webpack-merge](https://webpack.js.org/guides/production/)

# %% [markdown]
# - `webpack-merge` is a utility that allows you to easily merge multiple Webpack configuration files together. This is particularly useful when you want to maintain separate configurations for development and production environments while sharing common settings between them.
#
# - With `webpack-merge`, you can create a base configuration file that contains the shared settings, and then create separate configuration files for development and production that extend the base configuration. This helps to keep your configuration organized and reduces duplication.

# %% [markdown]
# #### Template Repositories

# %% [markdown]
# ### JSON

# %% [markdown]
# #### Intro

# %% [markdown]
# - **JSON** stands for **_JavaScript Object Notation_**. It is a lightweight data-interchange format that is easy for humans to read and write, and easy for machines to parse and generate. JSON is often used for transmitting data in web applications between a server and a client.
#
# - In simpler terms, _JSON_ is a way to represent data as a structured text format that can be easily shared and understood by both humans and computers. It uses a syntax that is similar to JavaScript objects, making it easy to work with in JavaScript applications. JSON is commonly used for `external servers`, `APIs`, `configuration files`, and `data storage`.

# %% [markdown]
# - The basic syntax of JSON includes:
#     - Data is represented in key-value pairs, where keys are strings and values can be strings, numbers, booleans, arrays, or other JSON objects.
#     - Objects are enclosed in curly braces `{}` and arrays are enclosed in square brackets `[]`.
#     - Keys and string values must be enclosed in double quotes `"`.
#
# - Example:
# ```json
#     {
#         "name": "John Doe",
#         "age": 30,
#         "isStudent": false,
#         "hobbies": ["reading", "gaming", "coding"],
#         "address": {
#             "street": "123 Main St",
#             "city": "Anytown",
#             "country": "USA"
#         },
#         "members": [
#             {
#                 "name": "Molecule Man",
#                 "age": 29,
#                 "secretIdentity": "Dan Jukes",
#                 "powers": ["Radiation resistance", "Turning tiny", "Radiation blast"]
#             },
#             {
#                 "name": "Madame Uppercut",
#                 "age": 39,
#                 "secretIdentity": "Jane Wilson",
#                 "powers": [
#                     "Million tonne punch",
#                     "Damage resistance",
#                     "Superhuman reflexes"
#                 ]
#             }
#         ]
#     }
# ```

# %% [markdown]
# #### Reading & Writing JSON

# %% [markdown]
# - [JSON formatter website](https://jsonformatter.curiousconcept.com/)

# %% [markdown]
# - Reading JSON data in JavaScript can be done using the `JSON.parse()` method, which takes a JSON string and converts it into a JavaScript object.
#
# - Writing JSON data can be done using the `JSON.stringify()` method, which takes a JavaScript object and converts it into a JSON string.
#
# 1. `JSON.parse()` is used to read JSON data and convert it into a JavaScript object. It takes a JSON string as input and returns the corresponding JavaScript object.
#
#     - Example:
#         ```javascript
#             const jsonString = '{"name": "John", "age": 30}';
#             const jsonObject = JSON.parse(jsonString);
#             console.log(jsonObject.name); // Output: John
#             console.log(jsonObject.age); // Output: 30
#         ```
#
#     - Uses:
#         * When you receive JSON data from an API or a server, you can use `JSON.parse()` to convert that data into a JavaScript object that you can work with in your code.
#
#         * When you read JSON data from a file or a string, you can use `JSON.parse()` to convert it into a JavaScript object for further processing.
#
# 2. `JSON.stringify()` is used to write JSON data by converting a JavaScript object into a JSON string. It takes a JavaScript object as input and returns a JSON string representation of that object.
#
#     - Example:
#         ```javascript
#             const jsonObject = { name: "John", age: 30 };
#             const jsonString = JSON.stringify(jsonObject);
#             console.log(jsonString); // Output: '{"name":"John","age":30}'
#         ```
#
#     - Uses:
#         * When you want to send data to a server or an API, you can use `JSON.stringify()` to convert your JavaScript object into a JSON string that can be transmitted over the network.
#
#         * When you want to save data to a file or local storage, you can use `JSON.stringify()` to convert your JavaScript object into a JSON string that can be easily stored and retrieved later.

# %% [markdown]
# - A more complex example of using both `JSON.parse()` and `JSON.stringify()` together:
#
# ```javascript
#     // Original JavaScript object
#     const originalObject = {
#         name: "Alice",
#         age: 25,
#         hobbies: ["reading", "hiking", "coding"]
#     };
#
#     // Convert the JavaScript object to a JSON string
#     const jsonString = JSON.stringify(originalObject);
#     console.log(jsonString); // Output: '{"name":"Alice","age":25,"hobbies":["reading","hiking","coding"]}'
#
#     // Convert the JSON string back to a JavaScript object
#     const parsedObject = JSON.parse(jsonString);
#     console.log(parsedObject); // Output: { name: 'Alice', age: 25, hobbies: [ 'reading', 'hiking', 'coding' ] }
# ```

# %% [markdown]
# # JS In the Real World

# %% [markdown]
# ### Linting

# %% [markdown]
# #### Linters

# %% [markdown]
# - **Linting** is the process of analyzing code to identify and report potential errors, bugs, stylistic issues, and other problems.
#
# - **A linter** is a tool that performs this analysis and provides feedback to developers about the quality and consistency of their code. It is a tool that will scan your code with a set of style rules and will report any errors to you that they find. In some cases, they can even auto-fix the errors! There are many linters that exist for JavaScript but by far the most common one is [ESLint](https://eslint.org/).

# %% [markdown]
# #### Formatters

# %% [markdown]
# - Formatters: A code formatter is a tool that automatically formats your code according to a specified style guide. It helps to maintain consistent code formatting across a project, making it easier to read and understand. One of the most popular code formatters for JavaScript is [Prettier](https://prettier.io/).
# - Prettier can be used in conjunction with ESLint to ensure that your code is not only free of errors but also consistently formatted.

# %% [markdown]
# ### Form Validation with JS

# %% [markdown]
# #### The Constraint Validation API

# %% [markdown]
# - The **Constraint Validation API** is a built-in JavaScript API that provides a way to validate form inputs based on constraints defined in the HTML markup. It allows developers to easily check if form fields meet certain criteria (such as required fields, pattern matching, or value ranges) before submitting the form.
#
# - The API provides properties and methods to access the validity state of form elements, display custom error messages, and prevent form submission if the validation fails. It is a powerful tool for enhancing user experience by providing immediate feedback on form input errors without needing to rely on server-side validation.
#
# - An example of how it works:
#
# ```html
#     <form id="myForm">
#         <input type="text" id="username" required pattern="[A-Za-z]{3,}" title="Username must be at least 3 characters long and contain only letters.">
#         <input type="email" id="email" required>
#         <button type="submit">Submit</button>
#     </form>
#
#     <script>
#         const form = document.getElementById('myForm');
#         form.addEventListener('submit', function(event) {
#             if (!form.checkValidity()) {
#                 event.preventDefault(); // Prevent form submission if validation fails
#                 alert('Please fill out the form correctly.'); // Show an error message
#             }
#         });
#     </script>

# %% [markdown]
# - Read more on this: https://developer.mozilla.org/en-US/docs/Learn_web_development/Extensions/Forms/Form_validation#validating_forms_using_javascript

# %% [markdown]
# # Asynchronous JS & APIs

# %% [markdown]
# ### Asynchronous Code

# %% [markdown]
# #### Intorduction

# %% [markdown]
# - **Asynchronous code** is a type of programming that allows certain operations to run in the background without blocking the main thread of execution. This means that while an asynchronous operation is being performed (such as fetching data from an API or reading a file), the rest of the code can continue to run without waiting for that operation to complete.

# %% [markdown]
# #### Callbacks

# %% [markdown]
# - Callback: A callback is a function that is passed as an argument to another function and is executed after a certain event or operation has completed.
#
# - Callbacks are commonly used in asynchronous programming to handle the results of asynchronous operations.
#
# - For example, when making an API request, you can pass a callback function that will be called with the response data once the request is complete.

# %% [markdown]
# - Example:
# ```javascript
#     function fetchData(callback) {
#         setTimeout(() => {
#             const data = { name: "John", age: 30 };
#             callback(data); // Call the callback function with the fetched data
#         }, 2000); // Simulate a delay of 2 seconds
#     }
#
#     fetchData(function(result) {
#         console.log("Data received:", result); // This will log the fetched data after 2 seconds
#     });
# ```
# - In this example, the `fetchData` function simulates an asynchronous operation using `setTimeout`. It takes a callback function as an argument, which is called with the fetched data after a delay of 2 seconds. The callback function is executed once the data is available, allowing us to handle the result of the asynchronous operation.
# - In simpler terms, in the example above, we have a function `fetchData` that simulates fetching data from an API. It takes a callback function as an argument, which will be called once the data is "fetched". The `setTimeout` function is used to simulate a delay in fetching the data. After 2 seconds, the callback function is called with the fetched data, allowing us to handle the result of the asynchronous operation.

# %% [markdown]
# #### Promises

# %% [markdown]
# - Promises are a modern way to handle asynchronous operations in JavaScript. A promise is an object that represents the eventual completion (or failure) of an asynchronous operation and its resulting value.
#
# - A promise can be in one of three states: pending, fulfilled, or rejected. When a promise is fulfilled, it means that the asynchronous operation completed successfully and the promise has a value. When a promise is rejected, it means that the asynchronous operation failed and the promise has a reason for the failure.
#
# - In simpler terms, a promise is like a placeholder for a value that will be available in the future. It allows you to write asynchronous code in a more readable and manageable way, avoiding the "callback hell" that can occur with nested callbacks.

# %% [markdown]
# - Example of promises:
# ```javascript
#     function fetchData() {
#         return new Promise((resolve, reject) => {
#             setTimeout(() => {
#                 const data = { name: "John", age: 30 };
#                 resolve(data); // Resolve the promise with the fetched data
#             }, 2000); // Simulate a delay of 2 seconds
#         });
#     }
#
#     fetchData()
#         .then(result => {
#             console.log("Data received:", result); // This will log the fetched data after 2 seconds
#         })
#         .catch(error => {
#             console.error("Error fetching data:", error); // Handle any errors that occur during the fetch
#         });
# ```
# - In this example, the `fetchData` function returns a promise that simulates fetching data from an API. The promise is created using the `Promise` constructor, which takes a function with `resolve` and `reject` parameters. Inside the function, we simulate an asynchronous operation using `setTimeout`. After 2 seconds, we call `resolve` with the fetched data to indicate that the operation was successful. We can then use the `.then()` method to handle the fulfilled state of the promise and access the result, and the `.catch()` method to handle any errors that may occur during the fetch operation.

# %% [markdown]
# ### Working with APIs

# %% [markdown]
# #### Intro

# %% [markdown]
# - **Application Programming Interfaces (APIs)** are sets of rules and protocols that allow different software applications to communicate with each other. They define how requests and responses should be structured, what data can be accessed, and how to interact with the functionality provided by the API.
#
# - In simpler terms, an API is like a contract between two software applications that allows them to talk to each other and exchange data or perform actions. APIs are commonly used in web development to enable communication between a client (such as a web browser) and a server, allowing developers to access data and functionality from external services or databases.

# %% [markdown]
# - **API Key:** An API key is a unique identifier that is used to authenticate requests made to an API. It is typically a long string of characters that is generated by the API provider and is required to access certain features or data from the API. API keys are used to track and control how the API is being used, and they help to prevent unauthorized access to the API. When making a request to an API, you usually need to include your API key in the request headers or as a query parameter to authenticate your request and gain access to the API's resources.

# %% [markdown]
# #### Fetching Data

# %% [markdown]
# - `fetch()` is a built-in JavaScript function that allows you to make network requests to retrieve resources from a server. It returns a promise that resolves to the response of the request, which can be processed to extract the data.
#
# - Example:
# ```javascript
#     // URL (required), options (optional)
#     fetch('https://url.com/some/url')
#         .then(function(response) {
#             // Successful response :)
#         })
#         .catch(function(err) {
#             // Error :(
#     });
# ```
# - In this example, we use the `fetch()` function to make a GET request to the specified URL. The `fetch()` function returns a promise that resolves to the response of the request. We can use the `.then()` method to handle the successful response and process the data, and the `.catch()` method to handle any errors that may occur during the fetch operation.

# %% [markdown]
# ### Async and Wait

# %% [markdown]
# #### Intro

# %% [markdown]
# - `async` and `await` are keywords in JavaScript that are used to work with promises in a more synchronous-looking way. They allow you to write asynchronous code that is easier to read and understand.
#
# - The `async` keyword is used to declare a function as asynchronous, which means that it can contain `await` expressions.
#
# - The `await` keyword is used to pause the execution of an asynchronous function until a promise is resolved, allowing you to write code that looks and behaves more like synchronous code.

# %% [markdown]
# - The syntax for an asynchronous function is as follows:
#
# ```javascript
#     async function myAsyncFunction() {
#         // Asynchronous code goes here
#     }
# ```
#
# - Example of using `async` and `await`:
#
# ```javascript
#     async function fetchData() {
#         try {
#             const response = await fetch('https://url.com/some/url');
#             const data = await response.json();
#             console.log(data); // Process the fetched data
#         } catch (error) {
#             console.error('Error fetching data:', error); // Handle any errors that occur during the fetch
#         }
#     }
#
#     fetchData(); // Call the asynchronous function to fetch data
# ```
# - In this example, we define an asynchronous function `fetchData` using the `async` keyword. Inside the function, we use the `await` keyword to pause the execution until the `fetch()` promise is resolved and we receive the response. We then use `await` again to parse the response as JSON. If any errors occur during the fetch operation, they are caught in the `catch` block and logged to the console. Finally, we call the `fetchData()` function to execute the asynchronous code and fetch the data.

# %% [markdown]
# #### Error Handling

# %% [markdown]
# - To handle errors in asynchronous code that uses `async` and `await`, you can use a `try...catch` block. The `try` block contains the code that may throw an error, and the `catch` block handles any errors that occur.
#
# - Example:
# ```javascript
#     async function fetchData() {
#         try {
#             const response = await fetch('https://url.com/some/url');
#             if (!response.ok) {
#                 throw new Error('Network response was not ok');
#             }
#             const data = await response.json();
#             console.log(data); // Process the fetched data
#         } catch (error) {
#             console.error('Error fetching data:', error); // Handle any errors that occur during the fetch
#         }
#     }
#
#     fetchData(); // Call the asynchronous function to fetch data
# ```
# - In this example, we use a `try...catch` block to handle errors that may occur during the asynchronous operation. If the `fetch()` request fails or if the response is not ok (e.g., a 404 or 500 status code), we throw an error with a custom message. The `catch` block then catches any errors that occur and logs them to the console, allowing us to handle the error gracefully without crashing the application.

# %% [markdown]
# # Testing JS

# %% [markdown]
# ### Testing Basics

# %% [markdown]
# #### Intro

# %% [markdown]
# - **Testing** is the process of evaluating a piece of code to determine whether it behaves as expected. It involves writing and running tests to verify that the code produces the correct output for given inputs and handles edge cases appropriately.
#
# - **Test-Driven Development (TDD)** is a software development approach where tests are written before the actual code is implemented. The process typically follows these steps:
#     1. _Write a test for a specific functionality or feature that you want to implement. This test will initially fail since the functionality has not been implemented yet._
#
#     2. _Write the minimum amount of code necessary to make the test pass. This code may not be perfect or complete, but it should be enough to satisfy the requirements of the test._
#
#     3. _Refactor the code to improve its structure, readability, and maintainability while ensuring that all tests still pass._
#
#     4. _Repeat this cycle for each new feature or functionality you want to add, continuously writing tests first and then implementing the code to make those tests pass._

# %% [markdown]
# - There are many test-running frameworks available for JavaScript, such as [Jest](https://jestjs.io/), [Mocha](https://mochajs.org/), [Jasmine](https://jasmine.github.io/), [Tape](https://github.com/substack/tape), and more. These frameworks provide tools and utilities to help you write and run your tests effectively.

# %% [markdown]
# #### Using Jest

# %% [markdown]
# - **Jest** is a popular JavaScript testing framework that provides a simple and powerful way to write and run tests for your JavaScript code. It is widely used in the JavaScript community and offers features such as snapshot testing, mocking, and code coverage analysis.

# %% [markdown]
# - Below are steps to get Jest up and running in your project:
#     1. **_Step 1: Install Jest as a development dependency in your project:_**
#
#     ```bash
#         npm install --save-dev jest
#     ```
#     - This command installs the Jest testing framework as a development dependency in your project. The `--save-dev` flag indicates that Jest is only needed for development purposes and will not be included in the production build of your application.
#
#     2. **_Step 2: Add a test script to your `package.json` file:_**
#
#     ```json
#         {
#             "scripts": {
#                 "test": "jest"
#             }
#         }
#     ```
#     - This adds a new script called `test` to your `package.json` file, which allows you to run your tests using the command `npm test`. When you run this command, Jest will look for test files in your project and execute them.
#
#     3. **_Step 3: Create a test file and write your tests:_**
#     - Create a new file in your project (e.g., `sum.test.js`) and write your test cases using Jest's testing syntax. For example:
#
#     ```javascript
#         // sum.js
#         function sum(a, b) {
#             return a + b;
#         }
#         module.exports = sum;
#
#         // sum.test.js
#         const sum = require('./sum');
#
#         test('adds 1 + 2 to equal 3', () => {
#             expect(sum(1, 2)).toBe(3);
#         });
#     ```
#     - In this example, we have a simple function `sum` that takes two numbers and returns their sum. We then create a test file `sum.test.js` where we import the `sum` function and write a test case using Jest's `test` function. The test checks if calling `sum(1, 2)` returns `3` using the `expect` and `toBe` matchers provided by Jest.
#
#     4. **_Step 4: Run your tests:_**
#
#     ```bash
#         npm test
#     ```
#     - This command runs the tests defined in your test files using Jest. Jest will execute the tests and provide feedback on whether they passed or failed, along with any error messages if applicable.
#
# - By following these steps, you can set up Jest in your project and start writing and running tests to ensure the correctness of your JavaScript code. Jest provides a rich set of features and utilities to help you write effective tests and maintain the quality of your codebase.

# %% [markdown]
# #### Writing Basic Tests

# %% [markdown]
# - To write basic tests, you can use the `test` function provided by Jest to define a test case. Inside the test case, you can use various matchers (such as `toBe`, `toEqual`, `toContain`, etc.) to assert that the expected output matches the actual output of your code.
#
# - Example of writing basic tests with Jest:
#
# ```javascript
#     // sum.js
#     function sum(a, b) {
#         return a + b;
#     }
#     module.exports = sum;
#
#     // sum.test.js
#     const sum = require('./sum');
#
#     test('adds 1 + 2 to equal 3', () => {
#         expect(sum(1, 2)).toBe(3);
#     });
#
#     test('adds -1 + -1 to equal -2', () => {
#         expect(sum(-1, -1)).toBe(-2);
#     });
#
#     test('adds 0 + 0 to equal 0', () => {
#         expect(sum(0, 0)).toBe(0);
#     });
# ```
# - In this example, we have a simple `sum` function that takes two numbers and returns their sum. We then create a test file `sum.test.js` where we import the `sum` function and write multiple test cases using Jest's `test` function. Each test case checks if calling the `sum` function with specific inputs returns the expected output using the `expect` and `toBe` matchers provided by Jest. By running `npm test`, you can execute these tests and verify that the `sum` function behaves as expected for different input values.

# %% [markdown]
# # A Bit of Computer Science

# %% [markdown]
# ### Intro to CS

# %% [markdown]
# #### Pseudocode

# %% [markdown]
# - Pseudocode is a high-level description of an algorithm or a program that uses natural language and programming-like syntax to outline the logic and steps of a solution. It is not meant to be executed by a computer but rather serves as a tool for planning and communicating the structure of code before actual implementation.
#
# - Pseudocode allows developers to focus on the logic and flow of their code without getting bogged down by syntax and language-specific details. It is often used in the early stages of software development to brainstorm and design algorithms, as well as to communicate ideas between team members.
#
# - Syntax of a pseudocode can vary, but it typically includes:
#     - Descriptive variable names
#     - Indentation to indicate blocks of code
#     - Control structures such as loops and conditionals
#     - Comments to explain the purpose of different sections of code
#
# - Importance of pseudocode in web development:
#     1. **Planning and Design:** Pseudocode helps developers plan and design their code before writing it. It allows them to outline the logic and structure of their code, making it easier to identify potential issues and optimize the solution.
#
#     2. **Communication:** Pseudocode serves as a common language for developers to communicate their ideas and solutions. It can be shared with team members, stakeholders, or even used in documentation to explain how a particular feature or algorithm works.
#
#     3. **Problem Solving:** Writing pseudocode can help developers break down complex problems into smaller, more manageable steps. It allows them to focus on the logic of the solution without getting distracted by syntax errors or language-specific details.
#
#     4. **Learning and Teaching:** Pseudocode is often used in educational settings to teach programming concepts and algorithms. It provides a way for students to understand the underlying logic of code without needing to learn a specific programming language first.

# %% [markdown]
# - Example of a simple pseudocode for a function that calculates the factorial of a number:
#
# ```
#     FUNCTION factorial(n)
#         IF n < 0 THEN
#             RETURN "Error: Input must be a non-negative integer"
#         ELSE IF n == 0 THEN
#             RETURN 1
#         ELSE
#             result = 1
#             FOR i FROM 1 TO n DO
#                 result = result * i
#             END FOR
#             RETURN result
#         END IF
#     END FUNCTION
# ```

# %% [markdown]
# #### Algorithms Intro

# %% [markdown]
# - **Algorithms:** An algorithm is a step-by-step procedure or set of rules for solving a specific problem or performing a task. It is a well-defined sequence of instructions that takes an input and produces an output. Algorithms can be implemented in various programming languages and are fundamental to computer science and software development.
#
# - Importance of algorithms in web development:
#     1. **Efficiency:** Algorithms help optimize the performance of web applications by providing efficient solutions to common problems, such as sorting data, searching for information, and managing resources.
#
#     2. **Scalability:** As web applications grow in complexity and user base, efficient algorithms ensure that the application can handle increased traffic and data without significant performance degradation.
#
#     3. **User Experience:** Fast and responsive web applications enhance user experience. Efficient algorithms contribute to reducing load times, improving responsiveness, and providing a smoother interaction for users.
#
#     4. **Data Management:** Web applications often deal with large amounts of data. Algorithms help in organizing, processing, and retrieving this data efficiently, which is crucial for features like search functionality, recommendations, and data analysis.
#
#     5. **Security:** Algorithms play a role in securing web applications by providing methods for encryption, hashing, and authentication, which are essential for protecting user data and ensuring secure communication.

# %% [markdown]
# - Syntax of algorithms in JavaScript: Algorithms can be implemented in JavaScript using functions, loops, conditionals, and other programming constructs. The syntax will depend on the specific algorithm being implemented, but generally, it involves defining a function that takes input parameters, processes the data according to the algorithm's logic, and returns the desired output.
#
# - Example of a simple algorithm to find the maximum number in an array:
# ```javascript
#     function findMax(arr) {
#         if (arr.length === 0) {
#             return null; // Return null for an empty array
#         }
#         let max = arr[0]; // Initialize max to the first element
#         for (let i = 1; i < arr.length; i++) {
#             if (arr[i] > max) {
#                 max = arr[i]; // Update max if a larger number is found
#             }
#         }
#         return max; // Return the maximum number found
#     }
#
#     const numbers = [3, 7, 2, 9, 5];
#     console.log(findMax(numbers)); // Output: 9
# ```
# - In this example, we define a function `findMax` that takes an array of numbers as input. The function initializes a variable `max` to the first element of the array and then iterates through the array starting from the second element. If it finds a number that is greater than the current `max`, it updates `max` with that number. Finally, the function returns the maximum number found in the array. This is a simple algorithm that efficiently finds the maximum number in an array with a time complexity of O(n).

# %% [markdown]
# #### Data Structures Intro

# %% [markdown]
# - **Data Structures:** A data structure is a way of organizing and storing data in a computer so that it can be accessed and modified efficiently. Data structures provide a means to manage large amounts of data and enable efficient algorithms for searching, sorting, and manipulating that data.
#
# - Examples of DS:
#     1. **Arrays:** An array is a collection of elements that are stored in contiguous memory locations. It allows for efficient access to elements using an index and is commonly used for storing lists of data.
#
#     2. **Linked Lists:** A linked list is a linear data structure where each element (called a node) contains a value and a reference (or link) to the next node in the list. Linked lists allow for dynamic memory allocation and efficient insertion and deletion of elements.
#
#     3. **Stacks:** A stack is a data structure that follows the Last In, First Out (LIFO) principle. It allows for adding and removing elements from the top of the stack only. Stacks are commonly used for managing function calls, undo operations, and expression evaluation.
#
#     4. **Queues:** A queue is a data structure that follows the First In, First Out (FIFO) principle. It allows for adding elements to the back of the queue and removing elements from the front of the queue. Queues are commonly used for managing tasks, scheduling processes, and handling asynchronous events.
#
#     5. **Trees:** A tree is a hierarchical data structure that consists of nodes connected by edges. Each node can have zero or more child nodes, and there is one root node at the top of the hierarchy. Trees are commonly used for representing hierarchical relationships, such as file systems, organizational charts, and decision trees.
#
#     6. **Graphs:** A graph is a collection of nodes (or vertices) connected by edges. Graphs can be directed or undirected and can represent various types of relationships between entities, such as social networks, transportation networks, and dependency graphs.

# %% [markdown]
# - Importance of DS in web development:
#     1. **Data Management:** Data structures help manage and organize data efficiently, allowing for faster access and manipulation of data in web applications.
#
#     2. **Performance Optimization:** Choosing the right data structure can significantly improve the performance of algorithms and operations in web applications, leading to faster load times and better user experience.
#
#     3. **Scalability:** As web applications grow in complexity and user base, efficient data structures ensure that the application can handle increased data and traffic without significant performance degradation.
#
#     4. **Problem Solving:** Understanding different data structures allows developers to choose the most appropriate one for solving specific problems, such as searching, sorting, and managing relationships between data.
#
#     5. **Memory Management:** Data structures can help optimize memory usage in web applications by providing efficient ways to store and access data, which is crucial for performance and scalability.

# %% [markdown]
# - Example of a DS:
#     ```javascript
#         // Example of a simple stack data structure
#         class Stack {
#             constructor() {
#                 this.items = [];
#             }
#
#             // Add an element to the top of the stack
#             push(element) {
#                 this.items.push(element);
#             }
#
#             // Remove and return the top element of the stack
#             pop() {
#                 if (this.isEmpty()) {
#                     return null; // Return null if the stack is empty
#                 }
#                 return this.items.pop();
#             }
#
#             // Check if the stack is empty
#             isEmpty() {
#                 return this.items.length === 0;
#             }
#
#             // Get the size of the stack
#             size() {
#                 return this.items.length;
#             }
#         }
#
#         const stack = new Stack();
#         stack.push(1);
#         stack.push(2);
#         stack.push(3);
#         console.log(stack.pop()); // Output: 3
#         console.log(stack.size()); // Output: 2
#     ```
# - In this example, we define a simple `Stack` class that implements a stack data structure using an array to store the elements. The `push` method adds an element to the top of the stack, while the `pop` method removes and returns the top element. The `isEmpty` method checks if the stack is empty, and the `size` method returns the number of elements in the stack. This implementation allows us to manage a collection of elements in a Last In, First Out (LIFO) manner, which is useful for various applications such as managing function calls or undo operations in web applications.

# %% [markdown]
# #### DSA Intro

# %% [markdown]
# - DSA stands for **Data Structures and Algorithms**. It is a fundamental concept in computer science that involves the study of how data can be organized, stored, and manipulated efficiently using various data structures and algorithms.
#
# - Data Structures are ways to organize and store data in a computer so that it can be accessed and modified efficiently. Examples include arrays, linked lists, stacks, queues, trees, and graphs.

# %% [markdown]
# ### Recursive Methods

# %% [markdown]
# #### Intro

# %% [markdown]
# - **Recursion** is a programming technique where a function calls itself in order to solve a problem. A recursive function typically has two main components:
#     1. a base case that stops the recursion, and
#     2. a recursive case that breaks the problem into smaller subproblems and calls itself with those subproblems.
#
# - It’s used to take a big problem and start breaking it down into smaller and smaller pieces (“Divide and Conquer”) and continuing to feed their solutions back into the original function until some sort of answer is achieved and the whole chain unwinds.
#
# - The syntax:
#     ```javascript
#         function recursiveFunction(parameters) {
#             if (base case condition) {
#                 return base case result; // Base case to stop recursion
#             } else {
#                 // Recursive case: break the problem into smaller subproblems
#                 return recursiveFunction(smaller parameters); // Recursive call with modified parameters
#             }
#         }
#     ```

# %% [markdown]
# - Recursion is used for solving large problems because it allows you to break down a complex problem into smaller, more manageable subproblems. This can lead to cleaner and more elegant code, as well as making it easier to understand the logic of the solution. Additionally, some problems are naturally recursive in nature (such as tree traversal or factorial calculation), making recursion a more intuitive approach for solving them.
#
# - However, the limitations of recursion include:
#     1. **Performance Issues:** Recursive functions can lead to performance issues, especially if the recursion depth is too large. This can result in a stack overflow error if the function calls itself too many times without reaching the base case.
#
#     2. **Memory Usage:** Each recursive call adds a new frame to the call stack, which can consume a lot of memory if the recursion depth is too large.
#
#     3. **Complexity:** Recursive solutions can sometimes be less efficient than iterative solutions, especially if the recursive calls involve redundant calculations. This can lead to exponential time complexity in some cases.
#
#     4. **Debugging Difficulty:** Debugging recursive functions can be more challenging than iterative functions, as it can be harder to trace the flow of execution and understand how the recursive calls are interacting with each other.
#
#     5. **Readability:** While recursion can lead to cleaner code in some cases, it can also make code harder to read and understand, especially for developers who are not familiar with the concept of recursion.

# %% [markdown]
# - Types of problems to better be solved with recursion:
#     1. **Tree Traversal:** Recursion is often used to traverse tree data structures, such as binary trees or n-ary trees, where each node can have multiple child nodes.
#
#     2. **Divide and Conquer Algorithms:** Many algorithms that follow the divide and conquer approach, such as merge sort and quicksort, can be implemented using recursion.
#
#     3. **Backtracking Problems:** Problems that involve exploring all possible combinations or permutations, such as the N-Queens problem or the subset sum problem, can be effectively solved using recursion.
#
#     4. **Mathematical Problems:** Recursive functions are commonly used to solve mathematical problems, such as calculating factorials, Fibonacci numbers, or performing exponentiation.
#
#     5. **Dynamic Programming:** Some dynamic programming problems can be solved using recursion with memoization to optimize performance by avoiding redundant calculations.
#
#
# - Types of problems to better be solved with iteration:
#     1. **Simple Loops:** Problems that involve simple loops or iterations, such as summing a list of numbers or finding the maximum value in an array, can often be more efficiently solved using iteration.
#
#     2. **State Management:** Problems that require managing state across iterations, such as simulating a process or implementing a finite state machine, may be better suited for iterative solutions.
#
#     3. **Performance-Critical Code:** In performance-critical code where efficiency is paramount, iterative solutions may be preferred over recursive ones due to potential overhead from function calls and memory usage associated with recursion.
#
#     4. **Tail Recursion:** If a recursive function can be optimized into tail recursion (where the recursive call is the last operation performed), it may be more efficient to implement it iteratively to avoid potential stack overflow issues.
#
#     5. **Iterating Over Large Data Sets:** When dealing with large data sets, iterative solutions may be more memory-efficient than recursive ones, as they do not require additional stack frames for each recursive call.

# %% [markdown]
# #### More Concepts

# %% [markdown]
# - **Recursive Depth:** The maximum depth of recursive calls that a function can make before it reaches the base case. If the recursive depth exceeds the limit set by the programming language or environment, it can lead to a stack overflow error.
#
# - **Stack Overflow:** An error that occurs when the call stack exceeds its limit due to too many recursive calls. This can happen if the base case is not properly defined or if the recursion depth is too large.
#
# - _Importance of stack overflow in recursion:_ Stack overflow is a critical issue in recursion because it can cause a program to crash or become unresponsive. It occurs when the call stack exceeds its limit due to too many recursive calls, which can happen if the base case is not properly defined or if the recursion depth is too large. To avoid stack overflow, it is important to ensure that the base case is correctly defined and that the recursion depth is kept within reasonable limits. Additionally, using iterative solutions or optimizing recursive functions with techniques like tail recursion can help mitigate the risk of stack overflow in certain cases.

# %% [markdown]
# - Example of a recursive function to calculate the factorial of a number:
# ```javascript
#     function factorial(n) {
#         if (n < 0) {
#             return "Error: Input must be a non-negative integer"; // Base case for invalid input
#         } else if (n === 0) {
#             return 1; // Base case: factorial of 0 is 1
#         } else {
#             return n * factorial(n - 1); // Recursive case: n! = n * (n - 1)!
#         }
#     }
#
#     console.log(factorial(5)); // Output: 120
# ```
# - In this example, we define a recursive function `factorial` that calculates the factorial of a non-negative integer `n`. The function checks for invalid input (negative numbers) and returns an error message. For the base case of `n === 0`, it returns `1`, since the factorial of 0 is defined to be 1. For any other positive integer `n`, the function calls itself with `n - 1` and multiplies it by `n` to compute the factorial recursively.

# %% [markdown]
# - **_Example of recursion with stack overflow:_**
# ```javascript
#     function infiniteRecursion() {
#         return infiniteRecursion(); // This will cause a stack overflow error
#     }
#
#     infiniteRecursion(); // Calling the function will lead to a stack overflow
# ```
# - In this example, the `infiniteRecursion` function calls itself without a base case to stop the recursion. When we call `infiniteRecursion()`, it will keep calling itself indefinitely until the call stack exceeds its limit, resulting in a stack overflow error. This illustrates the importance of having a proper base case in recursive functions to prevent such issues.
#
#
# - **_The correct version of the example above:_**
# ```javascript
#     function safeRecursion(n) {
#         if (n <= 0) {
#             return "Base case reached"; // Base case to stop recursion
#         } else {
#             return safeRecursion(n - 1); // Recursive call with modified parameter
#         }
#     }
#
#     console.log(safeRecursion(5)); // Output: "Base case reached"
# ```
# - In this corrected version, the `safeRecursion` function includes a base case that checks if `n` is less than or equal to 0. If it is, the function returns a message indicating that the base case has been reached, which stops the recursion. Otherwise, it continues to call itself with `n - 1`, allowing the recursion to proceed until it eventually reaches the base case without causing a stack overflow error.

# %% [markdown]
# ### Time Complexity

# %% [markdown]
# #### Efficiency Basics

# %% [markdown]
# - The **efficiency** of an algorithm is a measure of how well it performs in terms of time and space resources. It is often expressed using Big O notation, which describes the upper bound of the algorithm's growth rate as the input size increases.
#
# - To measure the efficiency of an algorithm, we typically analyze its time complexity and space complexity.
#
# - **Time complexity** refers to how the running time of an algorithm changes with respect to the size of the input, while
# - **space complexity** refers to how the amount of memory used by an algorithm changes with respect to the size of the input.

# %% [markdown]
# - As an example:
# ```javascript
#     function oddNumbersLessThanTen() {
#         let currentNumber = 1;
#
#         while (currentNumber < 10) {
#             if (currentNumber % 2 !== 0) {
#             console.log(currentNumber);
#             }
#
#             currentNumber += 1;
#         }
#     }
#
# ```
# - The way to measure code efficiency is to evaluate how many ‘steps’ it takes to complete. If you know that one algorithm you write takes 5 steps and another one takes 20 steps to accomplish the same task, then you can say that the 5-step algorithm will always run faster than the 20-step algorithm on the same computer.
#
#  - Let’s go back to our oddNumbersLessThanTen function. How many steps does our algorithm take?
#     1. We assign the number 1 to a variable. That’s one step.
#
#     2. We have a loop. For each iteration of the loop, we do the following:
#         1. Compare currentNumber to see if it is less than 10. That is 1 step.
#         2. We then check if currentNumber is odd. That is 1 step.
#         3. If it is then we output it to the terminal. That’s 1 step every 2 iterations.
#         4. We increase currentNumber by 1. That is 1 step.
#
#     3. To exit the loop, we need to compare currentNumber one last time to see that it is not less than ten any more. That is one last step.
#
# - So there are 3 steps for every loop iteration and it iterates 9 times which is 27 steps. Then we have one step which iterates for only half the loop iteration which is 5 steps. Assigning an initial value to currentNumber and checking the exit condition of the loop is one step each. 27 + 5 + 1 + 1 = 34 steps.
#
# - Therefore, we can say our algorithm takes 34 steps to complete.

# %% [markdown]
# - On the example below, however, it becomes impossible to measure efficiency since it is dependent on the external input maxNumber. If maxNumber is 100, then the algorithm will take 334 steps. If maxNumber is 1000, then the algorithm will take 3004 steps. If maxNumber is 1000000, then the algorithm will take 3000004 steps. So we can see that the number of steps increases as maxNumber increases, and it becomes difficult to measure efficiency in a meaningful way.:
# ```javascript
#     function oddNumbers(maxNumber) {
#         let currentNumber = 1;
#
#         while (currentNumber < maxNumber) {
#             if (currentNumber % 2 !== 0) {
#             console.log(currentNumber);
#             }
#
#             currentNumber += 1;
#         }
#     }
# ```

# %% [markdown]
# #### Asymptotic Notations

# %% [markdown]
# - **Asymptotic notations** are mathematical tools used to describe the behavior of algorithms as the input size grows. They provide a way to analyze and compare the efficiency of algorithms in terms of their time and space complexity. The most common asymptotic notations are `Big O (O)`, `Big Omega (Ω)`, and `Big Theta (Θ)`.
#
# 1. **Big O Notation (O):** Big O notation describes the _upper bound of an algorithm's growth rate_. It provides an upper limit on the time or space complexity of an algorithm, indicating the _worst-case scenario_. For example, if an algorithm has a time complexity of O(n), it means that in the worst case, the running time will grow linearly with the input size. _**This is the most referenced because you need to be sure you write code that scales as input grows.**_
#
# 2. **Big Omega Notation (Ω):** Big Omega notation describes the _lower bound of an algorithm's growth rate_. It provides a lower limit on the time or space complexity of an algorithm, indicating the _best-case scenario_. For example, if an algorithm has a time complexity of Ω(n), it means that in the best case, the running time will grow at least linearly with the input size.
#
# 3. **Big Theta Notation (Θ):** Big Theta notation describes the _tight bound of an algorithm's growth rate_. It provides both an upper and lower limit on the time or space complexity of an algorithm, indicating the _average-case scenario_. For example, if an algorithm has a time complexity of Θ(n), it means that in the average case, the running time will grow linearly with the input size.

# %% [markdown]
# #### Big O Notation (O)

# %% [markdown]
# - **Big O** gives us a consistent way to measure the efficiency of an algorithm. _It gives us a measurement for the time it takes for an algorithm to run as the input grows so that you can directly compare the performance of two algorithms and pick the best one._
#
# - Big O is not a piece of code you can put your algorithm into and it tells you how efficient it is. You will need to measure how the number of steps changes as the data grows, and using this you can apply a Big O Notation to it and measure it against other algorithms. In many cases you’ll be using a data structure in which the ways you interact with it are well known, and in that case it’s easier to judge how it will scale as the input changes.

# %% [markdown]
# - The most common Big O Notations in the order of speed from the fastest to the slowest are:
#     1. **_O(1) - Constant Complexity:_** The algorithm takes the same amount of time to run regardless of the input size. For example, accessing an element in an array by its index is O(1) because it takes the same amount of time to access any element.
#
#     2. **_O(log n) - Logarithmic Complexity:_** The algorithm's running time increases logarithmically as the input size increases. For example, binary search on a sorted array is O(log n) because it halves the search space with each iteration.
#         - _It tells us that the number of steps an algorithm takes increases by 1 as the data doubles. That’s still pretty efficient when you think about it. Going from 5,000 to 10,000 data elements and only taking one additional step can scale really well._
#
#     3. **_O(n) - Linear Complexity:_** The algorithm's running time increases linearly _(as the number of items grows, the number of steps grows at exactly the same rate)_ with the input size. For example, iterating through an array to find a specific element is O(n) because it may require checking each element in the worst case.
#
#     4. **_O(n log n) - Linearithmic Complexity:_** The algorithm's running time increases in a linearithmic manner as the input size increases. For example, efficient sorting algorithms like merge sort and quicksort have a time complexity of O(n log n).
#
#     5. **_O(n^2) - Quadratic Complexity:_** The algorithm's running time increases quadratically with the input size. For example, a nested loop that iterates through an array twice is O(n^2) because it requires checking each element against every other element.
#
#     6. **_O(n^3) - Cubic Complexity:_** The algorithm's running time increases cubically with the input size. For example, a triple nested loop that iterates through an array three times is O(n^3) because it requires checking each element against every other element twice.
#
#     7. **_O(2^n) - Exponential Complexity:_** The algorithm's running time doubles with each additional element in the input. For example, the naive recursive solution to the Fibonacci sequence has a time complexity of O(2^n) because it generates a binary tree of function calls.
#
#     8. **_O(n!) - Factorial Complexity:_** The algorithm's running time increases factorially with the input size. For example, generating all permutations of a set of n elements has a time complexity of O(n!) because there are n! possible permutations.

# %% [markdown]
# ### Space Complexity

# %% [markdown]
# #### Basics

# %% [markdown]
# - **Space Complexity** refers to the amount of memory an algorithm uses in relation to the size of the input data. It is often expressed using Big O notation, similar to time complexity, to describe how the space requirements grow as the input size increases.
#
# - The memory used by an algorithm can be categorized into two types:
#     1. **Auxiliary Space:** This is the extra space or temporary space used by an algorithm during its execution. It does not include the space taken by the input data. For example, if an algorithm uses a temporary array to store intermediate results, the size of that array contributes to the auxiliary space.
#
#     2. **Input Space:** This is the space taken by the input data itself. For example, if an algorithm takes an array of size n as input, then the input space is O(n).
#
# - The _total space complexity_ of an algorithm is the _sum of the auxiliary space and the input space_. For example, if an algorithm has an auxiliary space of O(1) and an input space of O(n), then the total space complexity is O(n).
#
# - The memory used is _primary memory (RAM)_ and secondary memory (disk storage). The space complexity of an algorithm is concerned with the amount of primary memory used during the execution of the algorithm.

# %% [markdown]
# #### Asymptotic Notations

# %% [markdown]
# - We measure space complexity using the same asymptotic notations as time complexity, such as Big O (O), Big Omega (Ω), and Big Theta (Θ). These notations describe how the space requirements of an algorithm grow as the input size increases.
#
# - **Big O Notation (O):** Big O notation describes the upper bound of an algorithm's space complexity. It provides an upper limit on the amount of memory used by an algorithm, indicating the worst-case scenario. For example, if an algorithm has a space complexity of O(n), it means that in the worst case, the amount of memory used will grow linearly with the input size.
#
# - **Big Omega Notation (Ω):** Big Omega notation describes the lower bound of an algorithm's space complexity. It provides a lower limit on the amount of memory used by an algorithm, indicating the best-case scenario. For example, if an algorithm has a space complexity of Ω(n), it means that in the best case, the amount of memory used will grow linearly with the input size.
#
# - **Big Theta Notation (Θ):** Big Theta notation describes both the upper and lower bounds of an algorithm's space complexity. It provides a tight bound on the amount of memory used by an algorithm, indicating that the space requirements grow at a rate that is both upper and lower bounded by the same function. For example, if an algorithm has a space complexity of Θ(n), it means that the amount of memory used will grow linearly with the input size in both the best and worst cases.

# %% [markdown]
# #### Big O Notation (O)

# %% [markdown]
# - The Big O notations used to measure space complexity are similar to those used for time complexity, but they describe how the memory usage grows with respect to the input size. The most common Big O notations for space complexity, in order of increasing space requirements, are:
#     1. **O(1) - Constant Space Complexity:** The algorithm uses a fixed amount of memory regardless of the input size. For example, a function that swaps two variables uses O(1) space because it only requires a constant amount of memory to hold the temporary variable.
#
#     2. **O(log n) - Logarithmic Space Complexity:** The algorithm's space requirements grow logarithmically with the input size. For example, a recursive binary search algorithm has a space complexity of O(log n) because it uses a logarithmic amount of memory for the call stack.
#
#     3. **O(n) - Linear Space Complexity:** The algorithm's space requirements grow linearly with the input size. For example, an algorithm that creates a new array of the same size as the input has a space complexity of O(n).
#
#     4. **O(n log n) - Linearithmic Space Complexity:** The algorithm's space requirements grow at a rate of n log n with the input size. For example, some sorting algorithms have a space complexity of O(n log n).
#
#     5. **O(n^2) - Quadratic Space Complexity:** The algorithm's space requirements grow quadratically with the input size. For example, a 2D array of size n x n has a space complexity of O(n^2).
#
#     6. **O(n^3) - Cubic Space Complexity:** The algorithm's space requirements grow cubically with the input size. For example, a 3D array of size n x n x n has a space complexity of O(n^3).
#
#     7. **O(2^n) - Exponential Space Complexity:** The algorithm's space requirements double with each additional element in the input. For example, a recursive algorithm that generates all subsets of a set has a space complexity of O(2^n) because it requires storing all possible subsets.
#
#     8. **O(n!) - Factorial Space Complexity:** The algorithm's space requirements grow factorially with the input size. For example, a recursive algorithm that generates all permutations of a set has a space complexity of O(n!) because it requires storing all possible permutations.

# %% [markdown]
# ### Common DSA

# %% [markdown]
# ### HashMap Data Structure

# %% [markdown]
# # Intermediate Git
